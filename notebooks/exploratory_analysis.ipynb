# %% [markdown]
# ## Explorační analýza dat o veřejných zakázkách

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from webpages.preprocessing import Preprocessor

plt.rcParams.update({'font.size': 14})

# %% [markdown]
# Načtení dat:

# %%
p = Preprocessor('../data_2')

# %%
dataframes = p.get_dataframes()

# %%
def basic_stats(df):
    print(f"Počet řádek je {df.shape[0]} a počet sloupců je {df.shape[1]}")
    print(f"Statitiky pro číselné příznaky:")
    display(df.describe())
    print(f"Chybějící hodnoty v %:")
    display(df.isna().sum() / df.shape[0] * 100)
    print(f"Příklad záznamů z tabulky:")
    display(df.head(10))

# %% [markdown]
# #### Informace o tabulce address:
#
# land_registry_number - Číslo popisné
# building_number - Číslo orientační

# %%
basic_stats(dataframes['address'])
# Out:
# Počet řádek je 10448 a počet sloupců je 9
# Statitiky pro číselné příznaky:
#                  id  land_registry_number     latitude    longitude
# count  10448.000000           9887.000000  5589.000000  5589.000000
# mean    5278.642420            876.601295    49.827102    15.504617
# std     3035.835012           1609.095186     0.912188     2.718896
# min        1.000000              0.000000    18.418805   -64.597298
# 25%     2632.750000            168.000000    49.575837    14.424908
# 50%     5295.500000            544.000000    50.038850    14.503491
# 75%     7907.250000           1190.000000    50.088160    16.632880
# max    10519.000000          78701.000000    60.182430   116.489593
# Chybějící hodnoty v %:
# id                       0.000000
# building_number         45.788668
# city                     0.076570
# country_code            39.203675
# land_registry_number     5.369449
# latitude                46.506508
# longitude               46.506508
# postal_code              2.488515
# street                  15.218224
# dtype: float64
# Příklad záznamů z tabulky:
#    id building_number                city country_code  land_registry_number  \
# 0   1             NaN               Praha          NaN                 682.0
# 1   2               1               Praha           CZ                 221.0
# 2   3             NaN    České Budějovice          NaN                   NaN
# 3   4             NaN                 NaN          NaN                   NaN
# 4   5              91  Jablonec nad Nisou           CZ                4588.0
# 5   6             NaN               Tetín          NaN                   1.0
# 6   7             NaN           Pardubice          NaN                 107.0
# 7   8             NaN         Helvíkovice          NaN                  90.0
# 8   9              58               Praha           CZ                1552.0
# 9  10             NaN     Klatovy, 339 01          NaN                   NaN
#
#     latitude  longitude postal_code                  street
# 0        NaN        NaN       19016              Zalešanská
# 1  50.095041  14.403276       16000               Tychonova
# 2        NaN        NaN       37005                     NaN
# 3        NaN        NaN         NaN                     NaN
# 4  50.731404  15.174121       46601               Smetanova
# 5        NaN        NaN       26601  náměstí Kněžny Ludmily
# 6        NaN        NaN       53002                     NaN
# 7        NaN        NaN       56401                     NaN
# 8  50.049737  14.458768       14100               Michelská
# 9        NaN        NaN         NaN           Ostravská 169

# %% [markdown]
# #### Informace o tabulce company
#
# vat_id_number - DIČ
# organisation_id - IČO

# %%
basic_stats(dataframes['company'])
# Out:
# Počet řádek je 12311 a počet sloupců je 5
# Statitiky pro číselné příznaky:
#                  id    address_id
# count  12311.000000  12311.000000
# mean    6181.052148   4475.818049
# std     3555.202724   3214.241409
# min        1.000000      1.000000
# 25%     3101.500000   1575.500000
# 50%     6182.000000   4175.000000
# 75%     9259.500000   7229.500000
# max    12337.000000  10519.000000
# Chybějící hodnoty v %:
# id                  0.000000
# vat_id_number      50.483308
# company_name        0.000000
# organisation_id     3.890829
# address_id          0.000000
# dtype: float64
# Příklad záznamů z tabulky:
#    id vat_id_number                                 company_name  \
# 0   1  CZ7303070038                                   Dušan Pirc
# 1   2    CZ26031868                                 CB Auto a.s.
# 2   3           NaN                     Pes profesionál s. r. o.
# 3   4    CZ62738542          Severočeské komunální služby s.r.o.
# 4   5    CZ47538856                         JOHNNY SERVIS s.r.o.
# 5   6           NaN                                Explosia a.s.
# 6   7    CZ25286366                                   Dibaq a.s.
# 7   8           NaN  Royal Canin Czech & Slovak Republics s.r.o.
# 8   9           NaN                             RC-eltech s.r.o.
# 9  10           NaN                                Lada Tittlová
#
#   organisation_id  address_id
# 0        66442460           1
# 1        26031868           3
# 2        03566358           4
# 3        62738542           5
# 4        47538856           6
# 5        25291581           7
# 6        25286366           8
# 7        24663913           9
# 8        06909981          10
# 9             NaN           4

# %% [markdown]
# vat_id_number - DIČ
# organisation_id - IČO

# %% [markdown]
# Počet duplicitních DIČ v tabulce company:

# %%
dataframes['company']['vat_id_number'].value_counts()
# Out:
# vat_id_number
# CZ              8
# CZ699003219     4
# CZ25568752      3
# CZ25056646      3
# CZ699001005     3
#                ..
# CZ09967273      1
# CZ27314588      1
# CZ28100603      1
# CZ5607160922    1
# CZ26025272      1
# Name: count, Length: 6010, dtype: int64

# %% [markdown]
# Název firem s duplicitním DIČ: CZ699003219

# %%
dataframes['company'][dataframes['company']['vat_id_number'] == 'CZ699003219']
# Out:
#         id vat_id_number                 company_name organisation_id  \
# 85     109   CZ699003219  EXCALIBUR ARMY spol. s r.o.        64573877
# 1084  1107   CZ699003219   LIKVIDACE ODPADU CZ s.r.o.        24823473
# 2000  1943   CZ699003219   TATRA DEFENCE VEHICLE a.s.        24152269
# 8268  8252   CZ699003219     LIKVIDACE ODPADU CZ a.s.        24823473
#
#       address_id
# 85           119
# 1084        1199
# 2000         119
# 8268        1199

# %% [markdown]
# Počet duplicitních IČO v tabulce company:

# %%
dataframes['company']['organisation_id'].value_counts()
# Out:
# organisation_id
# 02483360    5
# 10645969    4
# 02225506    4
# 00351504    3
# 26432668    3
#            ..
# 65724976    1
# 19319762    1
# 46345949    1
# 25291408    1
# 26025272    1
# Name: count, Length: 11572, dtype: int64

# %% [markdown]
# Název firem s duplicitním IČO: 02483360

# %%
dataframes['company'][dataframes['company']['organisation_id'] == '02483360']
# Out:
#         id vat_id_number        company_name organisation_id  address_id
# 2318  2260           NaN  CLICKPORT s. r. o.        02483360        2335
# 6418  6355           NaN    CLICKPORT s.r.o.        02483360        2335
# 6861  6798           NaN   CLICK PORT s.r.o.        02483360        6253
# 7935  7919           NaN  Clikport, s. r. o.        02483360        2335
# 8504  8488           NaN  Clickport s. r. o.        02483360        7659

# %% [markdown]
# Příklad adresy firmy s duplicitním IČO a s jiným ID:

# %%
display(dataframes['address'][dataframes['address']['id'] == 2335])
display(dataframes['address'][dataframes['address']['id'] == 6253])
display(dataframes['address'][dataframes['address']['id'] == 7659])
# Out:
#         id building_number    city country_code  land_registry_number  \
# 2400  2335               5  Přerov           CZ                 406.0
#
#        latitude  longitude postal_code          street
# 2400  49.450775   17.44412      750 02  Velké Novosady
#         id building_number    city country_code  land_registry_number  \
# 6389  6253               5  Přerov           CZ                 406.0
#
#        latitude  longitude postal_code          street
# 6389  49.450775   17.44412      750 02  Velké novosady
#         id building_number    city country_code  land_registry_number  \
# 7706  7659               5  PŘEROV           CZ                 406.0
#
#        latitude  longitude postal_code          street
# 7706  49.450775   17.44412       75002  Velké Novosady

# %% [markdown]
# #### Informace o tabulce contact_person

# %%
basic_stats(dataframes['contact_person'])
# Out:
# Počet řádek je 3096 a počet sloupců je 5
# Statitiky pro číselné příznaky:
#                 id  contracting_authority_id
# count  3096.000000               3096.000000
# mean   1613.526486                325.934755
# std     908.873898                356.892660
# min       1.000000                  1.000000
# 25%     814.750000                 70.000000
# 50%    1626.500000                166.000000
# 75%    2400.250000                475.250000
# max    3174.000000               1364.000000
# Chybějící hodnoty v %:
# id                          0.0000
# email                       0.0323
# name                        0.0000
# surname                     0.0000
# contracting_authority_id    0.0000
# dtype: float64
# Příklad záznamů z tabulky:
#    id                          email     name    surname  \
# 0   1             matyasovaa@army.cz   Andrea  Matyášová
# 1   2           Igor.Mathias@army.cz     Igor    Mathias
# 2   3                 karchp@army.cz    Pavel      Karch
# 3   4  mistostarosta@obecbudetice.cz    Pavel       Huda
# 4   5               straka@nemobk.cz  Antonín     Straka
# 5   6             eva.sikova@ikem.cz      Eva     Siková
# 6   7               mlakovad@army.cz     Dana    Mlaková
# 7   8                skurekz@army.cz   Zdeněk     Škůrek
# 8   9    monika.dedicova@firebrno.cz   Monika   Dědičová
# 9  10        tatana.chajmova@cuzk.cz   Taťána   Chajmová
#
#    contracting_authority_id
# 0                         1
# 1                         1
# 2                         1
# 3                         2
# 4                         3
# 5                         4
# 6                         1
# 7                         1
# 8                         5
# 9                         6

# %% [markdown]
# Počet kontaktních osob na jednoho zadavatele:

# %%
view_contact = dataframes['contact_person']['contracting_authority_id'].value_counts()
display(view_contact)
print(f"Průměrný počet kontaktních osob na jednoho zadavatele: {view_contact.mean():.2f}")
print(f"Medián počtu kontaktních osob na jednoho zadavatele: {view_contact.median()}")
# Out:
# contracting_authority_id
# 1       479
# 57      102
# 110      96
# 79       89
# 112      75
#        ...
# 612       1
# 613       1
# 614       1
# 617       1
# 1364      1
# Name: count, Length: 1025, dtype: int64
# Průměrný počet kontaktních osob na jednoho zadavatele: 3.02
# Medián počtu kontaktních osob na jednoho zadavatele: 1.0

# %% [markdown]
# Nejvíce kontaktních osob na jednoho zadavatele má ID 1:

# %%
dataframes['contracting_authority'][dataframes['contracting_authority']['id'] == 1]
# Out:
#    id contracting_authority_name                             url  address_id
# 0   1        Ministerstvo obrany  https://nen.nipez.cz/profil/MO           2

# %% [markdown]
# #### Informace o tabulce contracting_authority

# %%
basic_stats(dataframes['contracting_authority'])
# Out:
# Počet řádek je 1286 a počet sloupců je 4
# Statitiky pro číselné příznaky:
#                 id    address_id
# count  1286.000000   1286.000000
# mean    710.594090   4783.945568
# std     384.585647   3080.662974
# min       1.000000      2.000000
# 25%     366.250000   1969.250000
# 50%     721.500000   5003.000000
# 75%    1042.750000   7371.750000
# max    1364.000000  10508.000000
# Chybějící hodnoty v %:
# id                            0.000000
# contracting_authority_name    0.000000
# url                           7.153966
# address_id                    0.000000
# dtype: float64
# Příklad záznamů z tabulky:
#    id                         contracting_authority_name  \
# 0   1                                Ministerstvo obrany
# 1   2                                      Obec Budětice
# 2   3                                  Nemocnice Blansko
# 3   4        Institut klinické a experimentální medicíny
# 4   5       Hasičský záchranný sbor Jihomoravského kraje
# 5   6                                   Zeměměřický úřad
# 6   7  Ředitelství silnic Zlínského kraje,příspěvková...
# 7  52        Hasičský záchranný sbor Středočeského kraje
# 8  53                                Město Nová Včelnice
# 9  54                            Město Lipník nad Bečvou
#
#                                             url  address_id
# 0                https://nen.nipez.cz/profil/MO           2
# 1      https://nen.nipez.cz/profil/obecbudetice          11
# 2  https://nen.nipez.cz/profil/NemocniceBlansko          13
# 3              https://nen.nipez.cz/profil/ikem          17
# 4            https://nen.nipez.cz/profil/HZSJmK          24
# 5                https://nen.nipez.cz/profil/ZU          26
# 6              https://nen.nipez.cz/profil/RSZK          28
# 7               https://nen.nipez.cz/profil/STC          53
# 8      https://nen.nipez.cz/profil/novavcelnice          55
# 9       https://nen.nipez.cz/profil/mestolipnik          59

# %% [markdown]
# ID adres s více než jedním zadavatelem, registrovaným na této adrese:

# %%
view_address = dataframes['contracting_authority']['address_id'].value_counts()
view_address[view_address > 1]
# Out:
# address_id
# 26      4
# 2353    4
# 327     4
# 134     3
# 517     3
# 567     3
# 1019    3
# 7       2
# 2405    2
# 1044    2
# 1726    2
# 321     2
# 1507    2
# 9480    2
# 3276    2
# 4717    2
# 970     2
# 756     2
# 2369    2
# 9277    2
# 8184    2
# 712     2
# 929     2
# 7669    2
# 6635    2
# 5841    2
# 1440    2
# 2193    2
# 631     2
# 2750    2
# 6391    2
# 2609    2
# 648     2
# 644     2
# 6459    2
# 28      2
# 2310    2
# 3778    2
# 2566    2
# 5730    2
# 7938    2
# 3458    2
# 2859    2
# 1352    2
# 7868    2
# 6201    2
# 1985    2
# Name: count, dtype: int64

# %% [markdown]
# Příklad pro ID adresy 26, zde se jedná o stejného zadavatele:

# %%
dataframes['contracting_authority'][dataframes['contracting_authority']['address_id'] == 26]
# Out:
#       id               contracting_authority_name  \
# 5      6                         Zeměměřický úřad
# 68   113     Český úřad zeměměřický a katastrální
# 435  415    Katastrální úřad pro Středočeský kraj
# 703  716  Katastrální úřad pro hlavní město Prahu
#
#                                   url  address_id
# 5      https://nen.nipez.cz/profil/ZU          26
# 68   https://nen.nipez.cz/profil/CUZK          26
# 435  https://nen.nipez.cz/profil/KUST          26
# 703  https://nen.nipez.cz/profil/KUPH          26

# %% [markdown]
# Příklad pro ID adresy 2353, zde se jedná o různé zadavatele:

# %%
dataframes['contracting_authority'][dataframes['contracting_authority']['address_id'] == 2353]
# Out:
#       id                         contracting_authority_name  \
# 293  338  Muzeum jihovýchodní Moravy ve Zlíně, příspěvko...
# 517  531       14l15 Baťův institut, příspěvková organizace
# 659  672                                CV Machining s.r.o.
# 893  905  Krajská knihovna Františka Bartoše ve Zlíně, p...
#
#                                     url  address_id
# 293    https://nen.nipez.cz/profil/MJVM        2353
# 517  https://nen.nipez.cz/profil/1415BI        2353
# 659  https://nen.nipez.cz/profil/vivacv        2353
# 893    https://nen.nipez.cz/profil/KFBZ        2353

# %% [markdown]
# Příklad této adresy:

# %%
dataframes['address'][dataframes['address']['id'] == 2353]
# Out:
#         id building_number  city country_code  land_registry_number  latitude  \
# 2418  2353             NaN  Zlín           CZ                7040.0       NaN
#
#       longitude postal_code      street
# 2418        NaN       76001  Vavrečkova

# %% [markdown]
# Příklad zadavetelů bez uvedené URL:

# %%
dataframes['contracting_authority'][dataframes['contracting_authority']['url'].isna()]
# Out:
#         id                         contracting_authority_name  url  address_id
# 33      78                                      Město Blovice  NaN         252
# 39      84                             Městys Chlum u Třeboně  NaN         330
# 57     102                                    Obec Zdechovice  NaN         409
# 62     107                                   Obec Hostěradice  NaN         434
# 69     114                                    Město Přibyslav  NaN         448
# ...    ...                                                ...  ...         ...
# 1217  1231                                      Obec Podmokly  NaN        9173
# 1228  1242  Sdružení zdravotnických zařízení II Brno,přísp...  NaN        9319
# 1243  1257                                        Obec Zaječí  NaN        9458
# 1251  1265                                           RTS,a.s.  NaN        9545
# 1278  1292  Metropolitní kapitula u svatého Václava v Olom...  NaN        9774
#
# [92 rows x 4 columns]

# %% [markdown]
# #### Informace o tabulce offer
#
# is_association_of_suppliers - Sdružení dodavatelů
# is_rejected_due_too_low - Nabídka byla zamítnuta, vzhledem k mimořádně nízké ceně
# is_withdrawn - Nabídka byla stáhnuta ze strany účastníka
# company_id - id účastníka
# procurement_id - id zúčastněné zakázky

# %%
basic_stats(dataframes['offer'])
# Out:
# Počet řádek je 70338 a počet sloupců je 8
# Statitiky pro číselné příznaky:
#                  id         price     price_vat    company_id  procurement_id
# count  70338.000000  5.613700e+04  5.664500e+04  70338.000000    70338.000000
# mean   35217.532074  1.790282e+07  1.595046e+09   2810.489437    16554.329139
# std    20309.575771  9.668657e+08  3.710351e+11   3100.402481     9132.428391
# min        1.000000 -9.758000e+03  0.000000e+00      1.000000        1.000000
# 25%    17636.250000  2.850000e+04  3.448500e+04    464.000000     8628.250000
# 50%    35220.500000  2.628000e+05  3.018950e+05   1499.000000    17247.000000
# 75%    52804.750000  1.224600e+06  1.385450e+06   4121.000000    24324.000000
# max    70389.000000  1.145797e+11  8.830292e+13  12337.000000    31627.000000
# Chybějící hodnoty v %:
# id                              0.000000
# is_association_of_suppliers     0.012795
# is_rejected_due_too_low         0.011374
# is_withdrawn                    0.012795
# price                          20.189656
# price_vat                      19.467429
# company_id                      0.000000
# procurement_id                  0.000000
# dtype: float64
# Příklad záznamů z tabulky:
#    id is_association_of_suppliers is_rejected_due_too_low is_withdrawn  \
# 0   1                        True                   False        False
# 1   2                       False                   False        False
# 2   3                       False                   False        False
# 3   4                        True                   False        False
# 4   5                       False                   False        False
# 5   6                       False                   False        False
# 6   7                       False                   False        False
# 7   8                        True                   False        False
# 8   9                       False                   False        False
# 9  10                       False                   False        False
#
#        price  price_vat  company_id  procurement_id
# 0       0.00       0.00           1               1
# 1    9832.02   11897.00           2               2
# 2  130000.00  130000.00           3               3
# 3       0.00       0.00           4               4
# 4    8468.00    9314.80           5               5
# 5   90525.00  109535.25           6               6
# 6       0.00       0.00           7               7
# 7       0.00       0.00           8               8
# 8  130000.00  130000.00          10              10
# 9        NaN        NaN          12              11

# %% [markdown]
# #### Informace o tabulce procurement
#
# bids_submission_deadline - lhůta pro podání nabídek, pokud byl zveřejněn
# code_from_nipez_codelist - NIPEZ kód
# contract_price_with_amendments - výsledná cena zakázky s dodatky
# date_of_contract_close - datum uzavření smlouvy s výhercem
# date_of_publication - datum zveřejnění na portálu
# public_contract_regime - režim veřejné zakázky
# type - typ veřejné zakázky (služby, stavební práce, dodávky) nebo koncese (stavební práce, služby)
# type_of_procedure - druh zadávacího postupu

# %%
basic_stats(dataframes['procurement'])
# Out:
# Počet řádek je 31553 a počet sloupců je 20
# Statitiky pro číselné příznaky:
#                  id  contract_price  contract_price_vat  \
# count  31553.000000    3.155300e+04        3.155300e+04
# mean   15845.277977    7.757189e+06        1.518298e+10
# std     9117.428120    1.077410e+08        2.563831e+12
# min        1.000000    0.000000e+00        0.000000e+00
# 25%     7963.000000    1.200000e+04        1.426179e+04
# 50%    15851.000000    1.704780e+05        2.028759e+05
# 75%    23739.000000    1.192696e+06        1.433850e+06
# max    31627.000000    1.239521e+10        4.553075e+14
#
#        contract_price_with_amendments  contract_price_with_amendments_vat  \
# count                    3.155300e+04                        3.155300e+04
# mean                     7.856799e+06                        1.518310e+10
# std                      1.081485e+08                        2.563831e+12
# min                      0.000000e+00                        0.000000e+00
# 25%                      1.200000e+04                        1.427800e+04
# 50%                      1.706400e+05                        2.031227e+05
# 75%                      1.195885e+06                        1.436875e+06
# max                      1.239521e+10                        4.553075e+14
#
#        contact_person_id  contracting_authority_id   supplier_id
# count       31553.000000              31553.000000  31553.000000
# mean          925.339175                154.307039   2948.949735
# std           775.734393                236.617830   3179.687165
# min             1.000000                  1.000000      1.000000
# 25%           293.000000                  1.000000    481.000000
# 50%           696.000000                 77.000000   1659.000000
# 75%          1419.000000                191.000000   4457.000000
# max          3174.000000               1364.000000  12336.000000
# Chybějící hodnoty v %:
# id                                     0.000000
# bids_submission_deadline              49.881152
# code_from_nipez_codelist               5.413114
# contract_price                         0.000000
# contract_price_vat                     0.000000
# contract_price_with_amendments         0.000000
# contract_price_with_amendments_vat     0.000000
# date_of_contract_close                 0.031693
# date_of_publication                    4.481349
# is_association_of_suppliers            0.022185
# procurement_name                       0.000000
# name_from_nipez_codelist               5.413114
# place_of_performance                  10.937153
# public_contract_regime                33.724210
# system_number                          0.000000
# type                                   0.063385
# type_of_procedure                      0.000000
# contact_person_id                      0.000000
# contracting_authority_id               0.000000
# supplier_id                            0.000000
# dtype: float64
# Příklad záznamů z tabulky:
#    id bids_submission_deadline code_from_nipez_codelist  contract_price  \
# 0   1                      NaN               15710000-8        38973.48
# 1   2                      NaN               50110000-9         9832.02
# 2   3                      NaN                      NaN       130000.00
# 3   4                      NaN               90511000-2        26580.00
# 4   5                      NaN               90500000-2         8468.00
# 5   6                      NaN               24612000-7        90525.00
# 6   7                      NaN               15710000-8       103600.35
# 7   8                      NaN               15710000-8        23508.00
# 8   9                      NaN               45000000-7      1078673.00
# 9  10                      NaN               03322000-2       130000.00
#
#    contract_price_vat  contract_price_with_amendments  \
# 0            44820.00                        38973.48
# 1            11896.74                         9832.02
# 2           130000.00                       130000.00
# 3            32161.80                        26580.00
# 4             9314.80                         8468.00
# 5           109535.25                        90525.00
# 6           119141.40                       103600.35
# 7            27034.20                        23508.00
# 8          1305194.33                      1078673.00
# 9           130000.00                       130000.00
#
#    contract_price_with_amendments_vat date_of_contract_close  \
# 0                            44820.00             2022-03-02
# 1                            11896.74             2023-11-23
# 2                           130000.00             2022-02-24
# 3                            32161.80             2022-03-07
# 4                             9314.80             2023-10-24
# 5                           109535.25             2022-03-31
# 6                           119141.40             2022-04-01
# 7                            27034.20             2022-04-28
# 8                          1305194.33             2023-11-24
# 9                           130000.00             2022-03-31
#
#   date_of_publication is_association_of_suppliers  \
# 0          2022-03-02                       False
# 1          2023-11-30                       False
# 2          2022-03-02                       False
# 3          2022-03-07                       False
# 4          2023-10-24                       False
# 5          2022-04-01                       False
# 6          2022-04-01                       False
# 7          2022-05-03                       False
# 8          2023-11-30                       False
# 9          2022-04-21                       False
#
#                                     procurement_name  \
# 0                  Výzva k rámcové dohodě č. 12/2022
# 1  DP-RD Prohlídka s výměnou oleje Š-Karoq 4x4 VP...
# 2  Nákup služebního psa 24. 2. 2022 - hlídkový ob...
# 3                  Výzva k rámcové dohodě č. 14/2022
# 4          RD 2022/25 Servis mobilních toalet 16. dp
# 5                  Výzva k rámcové dohodě č. 17/2022
# 6                  Výzva k rámcové dohodě č. 21/2022
# 7                  Výzva k rámcové dohodě č. 23/2022
# 8           Oprava vodních zdrojů Budětice, Vlkonice
# 9  Nákup služebního psa 31. 3. 2021 speciální pac...
#
#                             name_from_nipez_codelist place_of_performance  \
# 0   Průmyslová krmiva pro hospodářská a jiná zvířata       Liberecký kraj
# 1  Opravy a údržba motorových vozidel a příslušen...       Jihočeský kraj
# 2                                                NaN                  NaN
# 3                                        Sběr odpadu       Liberecký kraj
# 4     Služby související s likvidací odpadů a odpady     Středočeský kraj
# 5                                    Různé výbušniny       Liberecký kraj
# 6   Průmyslová krmiva pro hospodářská a jiná zvířata       Liberecký kraj
# 7   Průmyslová krmiva pro hospodářská a jiná zvířata       Liberecký kraj
# 8                                     Stavební práce        Plzeňský kraj
# 9                                Hospodářská zvířata                  NaN
#
#         public_contract_regime      system_number  \
# 0                          NaN  N006/22/V00004456
# 1                          NaN  N006/23/V00033550
# 2  Small-scale public contract  N006/22/V00004676
# 3                          NaN  N006/22/V00004924
# 4                          NaN  N006/23/V00030140
# 5                          NaN  N006/22/V00007031
# 6                          NaN  N006/22/V00007590
# 7                          NaN  N006/22/V00009380
# 8  Small-scale public contract  N006/23/V00034233
# 9  Small-scale public contract  N006/22/V00009384
#
#                                     type  \
# 0         Public contract for deliveries
# 1           Public contract for services
# 2         Public contract for deliveries
# 3           Public contract for services
# 4           Public contract for services
# 5           Public contract for services
# 6         Public contract for deliveries
# 7         Public contract for deliveries
# 8  Public contract for construction work
# 9         Public contract for deliveries
#
#                                    type_of_procedure  contact_person_id  \
# 0  Zadávání VZ na základě rámcové dohody bez obno...                  1
# 1  Zadávání VZ na základě rámcové dohody bez obno...                  2
# 2                                     Otevřená výzva                  1
# 3  Zadávání VZ na základě rámcové dohody bez obno...                  1
# 4  Zadávání VZ na základě rámcové dohody bez obno...                  3
# 5  Zadávání VZ na základě rámcové dohody bez obno...                  1
# 6  Zadávání VZ na základě rámcové dohody bez obno...                  1
# 7  Zadávání VZ na základě rámcové dohody bez obno...                  1
# 8                                     Uzavřená výzva                  4
# 9                                     Otevřená výzva                  1
#
#    contracting_authority_id  supplier_id
# 0                         1            1
# 1                         1            2
# 2                         1            3
# 3                         1            4
# 4                         1            5
# 5                         1            6
# 6                         1            7
# 7                         1            8
# 8                         2            9
# 9                         1           10

# %% [markdown]
# Příklad VZ s chybějícím datem uveřejnění na portálu NEN:

# %%
dataframes['procurement'][dataframes['procurement']['date_of_publication'].isna()]
# Out:
#           id bids_submission_deadline code_from_nipez_codelist  \
# 20        21                      NaN               72261000-2
# 25        53                      NaN               18222100-2
# 69        97                      NaN                      NaN
# 104      132                      NaN               38720000-8
# 166      194                      NaN               34144212-7
# ...      ...                      ...                      ...
# 31357  31432                      NaN               44111000-1
# 31358  31433                      NaN               31524120-2
# 31459  31533               2021-02-05               33100000-1
# 31465  31540                      NaN               72250000-2
# 31481  31556                      NaN               30213100-6
#
#        contract_price  contract_price_vat  contract_price_with_amendments  \
# 20               0.00                0.00                            0.00
# 25          746050.00           902721.00                       746050.00
# 69          109000.00           109000.00                       109000.00
# 104         374000.00           452540.00                       374000.00
# 166        8383011.00         10143443.31                      8383011.00
# ...               ...                 ...                             ...
# 31357         2892.00             3499.32                         2892.00
# 31358         2231.00             2699.51                         2231.00
# 31459      5566000.00          6734860.00                      5566000.00
# 31465      1876742.32          2270858.21                      1876742.32
# 31481      2750300.00          3327863.00                      2750300.00
#
#        contract_price_with_amendments_vat date_of_contract_close  \
# 20                                   0.00             2021-03-04
# 25                              902721.00             2023-11-29
# 69                              109000.00             2022-10-25
# 104                             452540.00             2023-11-27
# 166                           10143443.31             2023-11-30
# ...                                   ...                    ...
# 31357                             3499.32             2023-02-15
# 31358                             2699.51             2023-02-15
# 31459                          6734860.00             2021-03-03
# 31465                          2270858.21             2021-12-14
# 31481                          3327863.00             2019-12-09
#
#       date_of_publication is_association_of_suppliers  \
# 20                    NaN                       False
# 25                    NaN                       False
# 69                    NaN                       False
# 104                   NaN                       False
# 166                   NaN                       False
# ...                   ...                         ...
# 31357                 NaN                       False
# 31358                 NaN                       False
# 31459                 NaN                       False
# 31465                 NaN                       False
# 31481                 NaN                       False
#
#                                         procurement_name  \
# 20     Údržba a servis elektronického řídícího systém...
# 25                                      Obleky pro lezce
# 69     Nákup služebního psa 25.10. 2022 - speciální p...
# 104                    Časomíra pro soutěže pořádané HZS
# 166                                       CAS 30 Blovice
# ...                                                  ...
# 31357    OL - vyzdění Luxfer chodby KoP Kojetín, obj. 26
# 31358  OL - výměna pohybových snímačů světel KrP Přer...
# 31459          „Endoskopické věže pro gastroenterologii“
# 31465  Aktualizace datových zdrojů a technická podpor...
# 31481                        Msp - Obměna IS-MSp-PS 2019
#
#                 name_from_nipez_codelist place_of_performance  \
# 20         Podpora programového vybavení    Jihomoravský kraj
# 25                                Obleky     Středočeský kraj
# 69                                   NaN                  NaN
# 104                     Časová počitadla     Středočeský kraj
# 166    Cisternové automobilové stříkačky        Plzeňský kraj
# ...                                  ...                  ...
# 31357                  Stavební materiál       Olomoucký kraj
# 31358                     Stropní světla       Olomoucký kraj
# 31459             Zdravotnické přístroje       Liberecký kraj
# 31465        Systémové a podpůrné služby   Hlavní město Praha
# 31481                  Přenosné počítače                  NaN
#
#             public_contract_regime      system_number  \
# 20     Small-scale public contract  N006/21/V00003128
# 25     Small-scale public contract  N006/23/V00032215
# 69     Small-scale public contract  N006/22/V00031301
# 104    Small-scale public contract  N006/23/V00031202
# 166                            NaN  N006/23/V00034114
# ...                            ...                ...
# 31357  Small-scale public contract  N006/23/V00007173
# 31358  Small-scale public contract  N006/23/V00007172
# 31459  Above-limit public contract  N006/20/V00034138
# 31465  Small-scale public contract  N006/21/V00032832
# 31481  Below-limit public contract  N006/19/V00034241
#
#                                  type  \
# 20       Public contract for services
# 25     Public contract for deliveries
# 69     Public contract for deliveries
# 104    Public contract for deliveries
# 166    Public contract for deliveries
# ...                               ...
# 31357    Public contract for services
# 31358  Public contract for deliveries
# 31459  Public contract for deliveries
# 31465  Public contract for deliveries
# 31481  Public contract for deliveries
#
#                                        type_of_procedure  contact_person_id  \
# 20                                          Přímé zadání                  9
# 25                                        Uzavřená výzva                 52
# 69                                        Otevřená výzva                  1
# 104                                       Uzavřená výzva                 52
# 166    Zadávání VZ na základě rámcové dohody bez obno...                 96
# ...                                                  ...                ...
# 31357                                       Přímé zadání                354
# 31358                                       Přímé zadání                354
# 31459                                    Otevřené řízení               2273
# 31465                                       Přímé zadání                545
# 31481                      Jednací řízení bez uveřejnění               3170
#
#        contracting_authority_id  supplier_id
# 20                            5           23
# 25                           52           52
# 69                            1           88
# 104                          52          125
# 166                          78          232
# ...                         ...          ...
# 31357                       161        10157
# 31358                       161         8488
# 31459                       713         2187
# 31465                       110         2027
# 31481                        55          105
#
# [1414 rows x 20 columns]

# %% [markdown]
# Překlad:

# %%
# translation for public_contract_regime
dict_public_contract_regime = {
    'Above-limit public contract': 'Nadlimitní veřejná zakázka',
    'Below-limit public contract': 'Podlimitní veřejná zakázka',
    'Small-scale public contract': 'Veřejná zakázka malého rozsahu',
    'Small-scale concession': 'Koncese malého rozsahu',
    'Concession': 'Koncese',
    'Below-threshold public procurement besides the procurement procedure': 'Podlimitní veřejná zakázka mimo zadávací řízení',
    'Zjednodušený režim': 'Zjednodušený režim',
}
# translation for type
dict_type = {
    'Public contract for deliveries' : 'Veřejná zakázka na dodávky',
    'Public contract for services' : 'Veřejná zakázka na služby',
    'Public contract for construction work' : 'Veřejná zakázka na stavební práce',
    'Service concessions' : 'Koncese na služby',
    'Concession for construction works' : 'Koncese na stavební práce',
}
dataframes['procurement']['public_contract_regime'] = dataframes['procurement']['public_contract_regime'].map(dict_public_contract_regime)
dataframes['procurement']['type'] = dataframes['procurement']['type'].map(dict_type)

# %% [markdown]
# Režim VZ dle výše ceny:

# %%
dataframes['procurement']['public_contract_regime'].unique()
# Out:
# array([nan, 'Veřejná zakázka malého rozsahu',
#        'Nadlimitní veřejná zakázka', 'Podlimitní veřejná zakázka',
#        'Zjednodušený režim', 'Koncese malého rozsahu',
#        'Podlimitní veřejná zakázka mimo zadávací řízení', 'Koncese'],
#       dtype=object)

# %% [markdown]
# Typ VZ:

# %%
dataframes['procurement']['type'].unique()
# Out:
# array(['Veřejná zakázka na dodávky', 'Veřejná zakázka na služby',
#        'Veřejná zakázka na stavební práce', 'Koncese na služby',
#        'Koncese na stavební práce', nan], dtype=object)

# %% [markdown]
# Druhy zadávacího postupu:

# %%
dataframes['procurement']['type_of_procedure'].unique()
# Out:
# array(['Zadávání VZ na základě rámcové dohody bez obnovení soutěže (mimo zadávací řízení)',
#        'Otevřená výzva', 'Uzavřená výzva', 'Otevřené řízení',
#        'Přímé zadání', 'Zjednodušené podlimitní řízení',
#        'Zadávání VZ na základě rámcové dohody s obnovením soutěže (mimo zadávací řízení)',
#        'Zadávání VZ na základě rámcové dohody bez obnovení soutěže na základě zadávacího řízení',
#        'Zadávání VZ na základě rámcové dohody s obnovením soutěže na základě zadávacího řízení',
#        'Užší řízení', 'Jednací řízení s uveřejněním', 'Zadávání VZ v DNS',
#        'Jednací řízení bez uveřejnění',
#        'Řízení pro zadání veřejné zakázky ve zjednodušeném režimu',
#        'Řízení se soutěžním dialogem', 'E-aukce malého rozsahu',
#        'Zadávání VZ na základě RS s jedním uchazečem v režimu ZVZ',
#        'Zadávání VZ na základě RS s jedním uchazečem (mimo režim ZVZ)',
#        'Zadávání VZ na základě RS s více uchazeči (mimo režim ZVZ)',
#        'Koncesní řízení', 'Přímé zadání u VZMR',
#        'Jednací řízení s uveřejněním (bez uveřejnění) - dle § 61 odst. 3 ZZVZ',
#        'Otevřená soutěž o návrh',
#        'Zadávání VZ na základě RS s více uchazeči v režimu ZVZ',
#        'Užší soutěž o návrh',
#        'Přímé zadání (v případě aplikace zákonné výjimky dle § 18-20 ZVZ)'],
#       dtype=object)

# %% [markdown]
# Funkce pro zobrazení procenta chybějících hodnot pro jednotlivé tabulky:

# %%
plt.rcParams.update({'font.size': 16})
def plot_missing_values(df, name):
    plt.figure(figsize=(12, 6))
    missing_values = df.isna().sum() / df.shape[0] * 100
    missing_values = missing_values[missing_values > 0].sort_values(ascending=False)
    barplot = sns.barplot(x=missing_values, y=missing_values.index)
    for p in barplot.patches:
        width = p.get_width()
        plt.text(width,
                 p.get_y() + p.get_height() / 2,
                 ' {:1.2f} %'.format(width),
                 ha = 'left')
    plt.title('Chybějící hodnoty v tabulce {}'.format(name))
    plt.xlabel('Procento chybějících hodnot')
    plt.ylabel('Název sloupce')
    plt.xlim(0, missing_values.max() * 1.1)
    plt.show()

# %%
plot_missing_values(dataframes['address'], 'address')

# %%
plot_missing_values(dataframes['contact_person'], 'contact_person')

# %%
plot_missing_values(dataframes['company'], 'company')

# %%
plot_missing_values(dataframes['contracting_authority'], 'contracting_authority')

# %%
plot_missing_values(dataframes['offer'], 'offer')

# %%
plot_missing_values(dataframes['procurement'], 'procurement')

# %% [markdown]
# Graf chybějících hodnot v tabulce procurement dle druhu zadávacího postupu:

# %%
grouped = dataframes['procurement'].groupby('type_of_procedure')

# %%
# for each group print percentage of missing values for column 'bids_submission_deadline'
# then print graph of missing values for column 'bids_submission_deadline' based on group sort by highest value on top
plt.rcParams.update({'font.size': 14})
data_for_plot = {}
for name, group in grouped:
    data_for_plot[name] = group['bids_submission_deadline'].isna().sum() / group.shape[0] * 100
plt.figure(figsize=(12, 6))
data_for_plot = {k: v for k, v in sorted(data_for_plot.items(), key=lambda item: item[1], reverse=True)}
barplot = sns.barplot(x=list(data_for_plot.values()), y=list(data_for_plot.keys()))
for p in barplot.patches:
    width = p.get_width()
    plt.text(width,
             p.get_y() + p.get_height() / 2 + 0.2,
             ' {:1.2f} %'.format(width),
             ha = 'left')
plt.title('Chybějící hodnoty v sloupci bids_submission_deadline dle druhu zadávacího postupu')
plt.xlabel('Procento chybějících hodnot')
plt.ylabel('Druh zadávacího postupu')
plt.xlim(0, max(data_for_plot.values()) * 1.1)
plt.show()
# Out:
# C:\Users\marti\PycharmProjects\bakalarka\venv\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %% [markdown]
# Zobrazení VZ v otevřeném řízení s chybějící lhůtou pro podání nabídek seřazené podle ceny zakázky s DPH a dodatky sestupně:

# %%
grouped.groups.keys()
ot = grouped.get_group('Otevřené řízení')
ot[ot['bids_submission_deadline'].isna()].sort_values(by='contract_price_vat', ascending=False)
# Out:
#           id bids_submission_deadline code_from_nipez_codelist  \
# 31329  31403                      NaN                      NaN
# 31340  31414                      NaN                      NaN
# 5621    5655                      NaN               33111610-0
# 9041   13995                      NaN                      NaN
# 27320  27354                      NaN               44520000-1
# 31339  31413                      NaN                      NaN
# 12692  12684                      NaN               33100000-1
# 21701  21674                      NaN                      NaN
# 21702  21675                      NaN                      NaN
# 445      472                      NaN               72000000-5
# 21189  21167                      NaN                      NaN
# 21190  21168                      NaN                      NaN
# 26418  26458                      NaN               45231300-8
# 12034  12068                      NaN               34144212-7
# 14097  14147                      NaN                      NaN
# 28529  28531                      NaN                      NaN
# 25354  25704                      NaN                      NaN
# 28530  28532                      NaN                      NaN
# 31401  31476                      NaN                      NaN
# 12254  12456                      NaN                      NaN
# 23393  23447                      NaN                      NaN
# 11679  11730                      NaN                      NaN
# 26311  26349                      NaN                      NaN
# 20772  20759                      NaN                      NaN
# 14067  14117                      NaN                      NaN
# 22558  22946                      NaN                      NaN
# 29268  29337                      NaN                      NaN
# 761      787                      NaN                      NaN
# 25283  25322                      NaN                      NaN
# 3875    3891                      NaN                      NaN
# 20410  20395                      NaN               37440000-4
# 26947  26985                      NaN               72220000-3
# 14068  14118                      NaN                      NaN
# 14066  14116                      NaN                      NaN
# 16311  16358                      NaN               50100000-6
# 14069  14119                      NaN                      NaN
# 3898    3914                      NaN                      NaN
# 10805  10853                      NaN               39299000-4
# 18267  18295                      NaN                      NaN
# 16013  16057                      NaN               18930000-7
# 26501  26542                      NaN                      NaN
# 14231  14282                      NaN                      NaN
# 6172    6184                      NaN                      NaN
# 29572  29639                      NaN                      NaN
# 30520  30586                      NaN                      NaN
# 6171    6183                      NaN                      NaN
# 31350  31425                      NaN                      NaN
# 14823  14873                      NaN               18332000-5
#
#        contract_price  contract_price_vat  contract_price_with_amendments  \
# 31329    2.796058e+09        3.075664e+09                    2.796058e+09
# 31340    4.674732e+08        5.656426e+08                    4.674732e+08
# 5621     1.440000e+08        1.742400e+08                    1.440000e+08
# 9041     9.917355e+07        1.200000e+08                    9.917355e+07
# 27320    2.319397e+07        2.806470e+07                    2.319397e+07
# 31339    2.047173e+07        2.477080e+07                    2.047173e+07
# 12692    1.786555e+07        2.161732e+07                    1.786555e+07
# 21701    1.782328e+07        2.049677e+07                    1.782328e+07
# 21702    1.782328e+07        2.049677e+07                    1.782328e+07
# 445      1.614300e+07        1.953303e+07                    1.614300e+07
# 21189    1.658870e+07        1.907700e+07                    1.658870e+07
# 21190    1.658870e+07        1.907700e+07                    1.658870e+07
# 26418    8.389100e+06        1.015081e+07                    8.389100e+06
# 12034    7.893481e+06        9.551112e+06                    7.893481e+06
# 14097    6.910773e+06        7.947389e+06                    6.910773e+06
# 28529    5.484160e+06        6.635834e+06                    5.484160e+06
# 25354    5.482380e+06        6.633680e+06                    5.482380e+06
# 28530    5.101608e+06        6.172945e+06                    5.101608e+06
# 31401    4.889574e+06        5.916384e+06                    4.889574e+06
# 12254    3.590369e+06        4.344346e+06                    3.590369e+06
# 23393    3.474373e+06        4.203991e+06                    3.474373e+06
# 11679    3.206591e+06        3.879975e+06                    3.206591e+06
# 26311    2.825618e+06        3.418998e+06                    2.825618e+06
# 20772    2.813000e+06        3.403730e+06                    2.813000e+06
# 14067    2.104280e+06        2.433096e+06                    2.104280e+06
# 22558    1.282417e+06        1.551724e+06                    1.282417e+06
# 29268    1.180000e+06        1.427800e+06                    1.180000e+06
# 761      9.780000e+05        1.183380e+06                    9.780000e+05
# 25283    8.270000e+05        1.000670e+06                    8.270000e+05
# 3875     7.965480e+05        9.638231e+05                    7.965480e+05
# 20410    5.900000e+05        7.139000e+05                    5.900000e+05
# 26947    4.375000e+05        5.293750e+05                    4.375000e+05
# 14068    3.711227e+05        4.366191e+05                    3.711227e+05
# 14066    2.703612e+05        3.271370e+05                    2.703612e+05
# 16311    2.479339e+05        3.000000e+05                    2.479339e+05
# 14069    2.110000e+05        2.553100e+05                    2.110000e+05
# 3898     1.239670e+05        1.500000e+05                    1.239670e+05
# 10805    3.596533e+04        4.351805e+04                    3.596533e+04
# 18267    2.152000e+03        2.603920e+03                    2.152000e+03
# 16013    0.000000e+00        0.000000e+00                    0.000000e+00
# 26501    0.000000e+00        0.000000e+00                    0.000000e+00
# 14231    0.000000e+00        0.000000e+00                    0.000000e+00
# 6172     0.000000e+00        0.000000e+00                    0.000000e+00
# 29572    0.000000e+00        0.000000e+00                    0.000000e+00
# 30520    0.000000e+00        0.000000e+00                    0.000000e+00
# 6171     0.000000e+00        0.000000e+00                    0.000000e+00
# 31350    0.000000e+00        0.000000e+00                    0.000000e+00
# 14823    0.000000e+00        0.000000e+00                    0.000000e+00
#
#        contract_price_with_amendments_vat date_of_contract_close  \
# 31329                        3.075664e+09             2021-11-19
# 31340                        5.656426e+08             2021-10-20
# 5621                         1.742400e+08             2023-01-24
# 9041                         1.200000e+08             2018-05-24
# 27320                        2.806470e+07             2019-08-21
# 31339                        2.477080e+07             2021-08-06
# 12692                        2.161732e+07             2015-09-04
# 21701                        2.049677e+07             2022-01-12
# 21702                        2.049677e+07             2022-01-12
# 445                          1.953303e+07             2023-10-25
# 21189                        1.907700e+07             2022-01-13
# 21190                        1.907700e+07             2022-01-13
# 26418                        1.015081e+07             2022-03-16
# 12034                        9.551112e+06             2023-10-20
# 14097                        7.947389e+06             2014-11-03
# 28529                        6.635834e+06             2015-01-20
# 25354                        6.633680e+06             2014-02-06
# 28530                        6.172945e+06             2013-09-27
# 31401                        5.916384e+06             2021-12-10
# 12254                        4.344346e+06             2022-06-08
# 23393                        4.203991e+06             2022-11-25
# 11679                        3.879975e+06             2020-12-14
# 26311                        3.418998e+06             2022-08-08
# 20772                        3.403730e+06             2014-12-23
# 14067                        2.433096e+06             2015-07-23
# 22558                        1.551724e+06             2022-06-06
# 29268                        1.427800e+06             2020-04-15
# 761                          1.183380e+06             2023-11-09
# 25283                        1.000670e+06             2023-04-27
# 3875                         9.638231e+05             2023-07-18
# 20410                        7.139000e+05             2023-07-10
# 26947                        5.293750e+05             2023-01-30
# 14068                        4.366191e+05             2015-11-10
# 14066                        3.271370e+05             2015-07-30
# 16311                        3.000000e+05             2023-09-14
# 14069                        2.553100e+05             2015-11-11
# 3898                         1.500000e+05             2023-08-07
# 10805                        4.351805e+04             2023-11-01
# 18267                        2.603920e+03             2023-08-21
# 16013                        0.000000e+00             2018-05-25
# 26501                        0.000000e+00             2016-05-04
# 14231                        0.000000e+00             2017-12-06
# 6172                         0.000000e+00             2019-06-20
# 29572                        0.000000e+00             1997-05-02
# 30520                        0.000000e+00             2016-10-12
# 6171                         0.000000e+00             2019-08-29
# 31350                        0.000000e+00             2017-11-02
# 14823                        0.000000e+00             2017-06-15
#
#       date_of_publication is_association_of_suppliers  \
# 31329          2023-03-16                       False
# 31340          2022-03-16                       False
# 5621           2022-10-17                       False
# 9041           2019-09-23                       False
# 27320          2023-04-24                       False
# 31339          2022-03-16                       False
# 12692          2015-06-03                       False
# 21701          2022-01-17                       False
# 21702          2022-01-17                       False
# 445            2023-11-29                       False
# 21189          2023-07-13                       False
# 21190          2023-07-13                       False
# 26418          2022-07-21                       False
# 12034          2023-10-23                       False
# 14097          2023-10-02                       False
# 28529          2023-03-22                       False
# 25354          2013-09-18                       False
# 28530          2023-03-27                       False
# 31401          2021-12-22                       False
# 12254          2022-06-09                       False
# 23393          2023-01-13                       False
# 11679          2023-05-28                       False
# 26311          2022-08-08                       False
# 20772          2014-10-17                       False
# 14067          2023-10-02                       False
# 22558          2022-06-06                       False
# 29268          2020-06-01                       False
# 761            2023-11-27                       False
# 25283          2023-05-22                       False
# 3875           2023-12-07                       False
# 20410          2023-07-26                       False
# 26947          2023-04-27                       False
# 14068          2023-10-02                       False
# 14066          2023-10-02                       False
# 16311          2023-09-18                       False
# 14069          2023-10-02                       False
# 3898           2023-12-07                       False
# 10805          2023-11-02                       False
# 18267                 NaN                       False
# 16013          2019-09-24                       False
# 26501          2020-05-25                       False
# 14231          2020-09-15                       False
# 6172           2019-09-27                       False
# 29572          2016-04-06                         NaN
# 30520          2016-04-11                       False
# 6171           2019-09-26                       False
# 31350          2019-03-25                       False
# 14823          2019-09-12                       False
#
#                                         procurement_name  \
# 31329  Zajištění komplexní dodávky a distribuce léčiv...
# 31340  Distribuce očkovací látky proti COVID-19 – Com...
# 5621     Experimentální magnetická rezonance - systém 7T
# 9041   Různé další speciální chemické látky a prostředky
# 27320       Rámcová dohoda - Euroklíč pro ČR 2019 - 2023
# 31339         Distribuce očkovacích látek proti COVID-19
# 12692                      Dodávka a servis CT přístroje
# 21701  Nakládání s ostatními a nebezpečnými odpady v ...
# 21702  Nakládání s ostatními a nebezpečnými odpady v ...
# 445         Rámcová dohoda - Řečové technologie - Část A
# 21189  Nakládání s ostatními a nebezpečnými odpady v ...
# 21190  Nakládání s ostatními a nebezpečnými odpady v ...
# 26418            II/353 Žďár nad Sázavou – ul. Jihlavská
# 12034                        CAS 20_Chlumec nad Cidlinou
# 14097  Hospic na Svatém Kopečku - rozšíření služeb a ...
# 28529   Obměna serverové infrastruktury - nové vyhlášení
# 25354  Filtrační zařízení tryskací komory a kelímkový...
# 28530       Dodávka a podpora videokonferenčního systému
# 31401                           Microsoft O365 - licence
# 12254  Rekonstrukce mostu přes potok Velká, Stěbořice...
# 23393                        Rekonstrukce obecního úřadu
# 11679                 Svoz komunálního odpadu – Brušperk
# 26311  Výstavba chodníků na horním konci v obci Stěbo...
# 20772  Vybudování centra diferencovaného zpracování d...
# 14067  Hospic na Svatém Kopečku - rozšíření služeb a ...
# 22558  Rekonstrukce venkovního přístupového schodiště...
# 29268  Návrh změny ÚPmB B5/19-CM, MČ Brno-Královo Pol...
# 761                                  TUPO-Výbuchové silo
# 25283  Projektova dokumentace pro provedení stavby a ...
# 3875                            Obnova osobních počítačů
# 20410  JN (OZP) - Pořízení 2 ks horizontálních solári...
# 26947  DS č. 1, RD o poskytování konzultačních a pora...
# 14068  Hospic na Svatém Kopečku - rozšíření služeb a ...
# 14066  Hospic na Svatém Kopečku - rozšíření služeb a ...
# 16311  Opravy služebních vozidel RENAULT na období 20...
# 14069  Hospic na Svatém Kopečku - rozšíření služeb a ...
# 3898                  Nákup xerografického papíru A4, A3
# 10805  RD (OZP) - Broušené sklo a produkty ze skla (o...
# 18267                                   Obalový materiál
# 16013                                     Vak na výstroj
# 26501  Projekční a inženýrské služby pro akci „Modern...
# 14231                     Technická podpora internetu MO
# 6172   Centralizované zadávání – Zajištění přijímání ...
# 29572                         Přístup do databáze EPOQUE
# 30520  Utilization of foreign experience in the sitin...
# 6171   Centralizované zadávání – Služba tiskového řeš...
# 31350  Zajištění komplexní dodávky a distribuce léčiv...
# 14823                                        Košile 2012
#
#                                 name_from_nipez_codelist  \
# 31329                                                NaN
# 31340                                                NaN
# 5621                       Jednotka magnetické resonance
# 9041                                                 NaN
# 27320                               Zámky, klíče a panty
# 31339                                                NaN
# 12692                             Zdravotnické přístroje
# 21701                                                NaN
# 21702                                                NaN
# 445    Informační technologie: poradenství, vývoj pro...
# 21189                                                NaN
# 21190                                                NaN
# 26418  Stavební práce pro vodovodní a kanalizační pot...
# 12034                  Cisternové automobilové stříkačky
# 14097                                                NaN
# 28529                                                NaN
# 25354                                                NaN
# 28530                                                NaN
# 31401                                                NaN
# 12254                                                NaN
# 23393                                                NaN
# 11679                                                NaN
# 26311                                                NaN
# 20772                                                NaN
# 14067                                                NaN
# 22558                                                NaN
# 29268                                                NaN
# 761                                                  NaN
# 25283                                                NaN
# 3875                                                 NaN
# 20410                               Vybavení pro fitness
# 26947            Systémové a technické poradenské služby
# 14068                                                NaN
# 14066                                                NaN
# 16311  Opravy a údržba vozidel a příslušenství k nim ...
# 14069                                                NaN
# 3898                                                 NaN
# 10805                                   Skleněné výrobky
# 18267                                                NaN
# 16013                                    Pytlíky a tašky
# 26501                                                NaN
# 14231                                                NaN
# 6172                                                 NaN
# 29572                                                NaN
# 30520                                                NaN
# 6171                                                 NaN
# 31350                                                NaN
# 14823                                             Košile
#
#        place_of_performance          public_contract_regime  \
# 31329                   NaN                             NaN
# 31340                   NaN                             NaN
# 5621     Hlavní město Praha      Nadlimitní veřejná zakázka
# 9041                    NaN                             NaN
# 27320                   NaN      Nadlimitní veřejná zakázka
# 31339                   NaN                             NaN
# 12692          Zlínský kraj      Nadlimitní veřejná zakázka
# 21701                   NaN      Nadlimitní veřejná zakázka
# 21702                   NaN      Nadlimitní veřejná zakázka
# 445         Česká republika                             NaN
# 21189                   NaN      Nadlimitní veřejná zakázka
# 21190                   NaN      Nadlimitní veřejná zakázka
# 26418         Kraj Vysočina      Nadlimitní veřejná zakázka
# 12034  Královéhradecký kraj                             NaN
# 14097                   NaN                             NaN
# 28529                   NaN      Nadlimitní veřejná zakázka
# 25354                   NaN                             NaN
# 28530                   NaN      Nadlimitní veřejná zakázka
# 31401                   NaN                             NaN
# 12254                   NaN  Veřejná zakázka malého rozsahu
# 23393                   NaN                             NaN
# 11679                   NaN                             NaN
# 26311                   NaN  Veřejná zakázka malého rozsahu
# 20772                   NaN                             NaN
# 14067                   NaN                             NaN
# 22558                   NaN                             NaN
# 29268                   NaN                             NaN
# 761                     NaN  Veřejná zakázka malého rozsahu
# 25283                   NaN                             NaN
# 3875                    NaN                             NaN
# 20410    Hlavní město Praha  Veřejná zakázka malého rozsahu
# 26947    Hlavní město Praha                             NaN
# 14068                   NaN                             NaN
# 14066                   NaN                             NaN
# 16311        Liberecký kraj  Veřejná zakázka malého rozsahu
# 14069                   NaN                             NaN
# 3898                    NaN                             NaN
# 10805    Hlavní město Praha  Veřejná zakázka malého rozsahu
# 18267                   NaN                             NaN
# 16013     Jihomoravský kraj      Nadlimitní veřejná zakázka
# 26501                   NaN                             NaN
# 14231                   NaN      Nadlimitní veřejná zakázka
# 6172                    NaN  Veřejná zakázka malého rozsahu
# 29572                   NaN      Podlimitní veřejná zakázka
# 30520                   NaN      Nadlimitní veřejná zakázka
# 6171                    NaN      Podlimitní veřejná zakázka
# 31350                   NaN      Nadlimitní veřejná zakázka
# 14823     Jihomoravský kraj      Nadlimitní veřejná zakázka
#
#            system_number                               type type_of_procedure  \
# 31329  N006/23/V00007207         Veřejná zakázka na dodávky   Otevřené řízení
# 31340  N006/22/V00005964          Veřejná zakázka na služby   Otevřené řízení
# 5621   N006/22/V00027136         Veřejná zakázka na dodávky   Otevřené řízení
# 9041   N006/19/V00027242         Veřejná zakázka na dodávky   Otevřené řízení
# 27320  N006/23/V00011308         Veřejná zakázka na dodávky   Otevřené řízení
# 31339  N006/22/V00005954          Veřejná zakázka na služby   Otevřené řízení
# 12692  N006/22/V00029607         Veřejná zakázka na dodávky   Otevřené řízení
# 21701  N006/22/V00000908          Veřejná zakázka na služby   Otevřené řízení
# 21702  N006/22/V00000908          Veřejná zakázka na služby   Otevřené řízení
# 445    N006/23/V00023568          Veřejná zakázka na služby   Otevřené řízení
# 21189  N006/23/V00019842          Veřejná zakázka na služby   Otevřené řízení
# 21190  N006/23/V00019842          Veřejná zakázka na služby   Otevřené řízení
# 26418  N006/22/V00000819  Veřejná zakázka na stavební práce   Otevřené řízení
# 12034  N006/23/V00029754         Veřejná zakázka na dodávky   Otevřené řízení
# 14097  N006/23/V00027488  Veřejná zakázka na stavební práce   Otevřené řízení
# 28529  N006/23/V00007293         Veřejná zakázka na dodávky   Otevřené řízení
# 25354  N006/23/V00013636                                NaN   Otevřené řízení
# 28530  N006/23/V00008349         Veřejná zakázka na dodávky   Otevřené řízení
# 31401  N006/21/V00033798          Veřejná zakázka na služby   Otevřené řízení
# 12254  N006/22/V00014749  Veřejná zakázka na stavební práce   Otevřené řízení
# 23393  N006/23/V00000934  Veřejná zakázka na stavební práce   Otevřené řízení
# 11679  N006/23/V00014859          Veřejná zakázka na služby   Otevřené řízení
# 26311  N006/22/V00020439  Veřejná zakázka na stavební práce   Otevřené řízení
# 20772  N006/23/V00020547                                NaN   Otevřené řízení
# 14067  N006/23/V00027508         Veřejná zakázka na dodávky   Otevřené řízení
# 22558  N006/22/V00014340  Veřejná zakázka na stavební práce   Otevřené řízení
# 29268  N006/20/V00012246          Veřejná zakázka na služby   Otevřené řízení
# 761    N006/23/V00030523         Veřejná zakázka na dodávky   Otevřené řízení
# 25283  N006/23/V00014148         Veřejná zakázka na dodávky   Otevřené řízení
# 3875   N006/23/V00034908         Veřejná zakázka na dodávky   Otevřené řízení
# 20410  N006/23/V00014432         Veřejná zakázka na dodávky   Otevřené řízení
# 26947  N006/23/V00011772          Veřejná zakázka na služby   Otevřené řízení
# 14068  N006/23/V00027521         Veřejná zakázka na dodávky   Otevřené řízení
# 14066  N006/23/V00027508         Veřejná zakázka na dodávky   Otevřené řízení
# 16311  N006/23/V00025923          Veřejná zakázka na služby   Otevřené řízení
# 14069  N006/23/V00027521         Veřejná zakázka na dodávky   Otevřené řízení
# 3898   N006/23/V00034893         Veřejná zakázka na dodávky   Otevřené řízení
# 10805  N006/23/V00027787         Veřejná zakázka na dodávky   Otevřené řízení
# 18267  N006/23/V00023915         Veřejná zakázka na dodávky   Otevřené řízení
# 16013  N006/19/V00027024         Veřejná zakázka na dodávky   Otevřené řízení
# 26501  N006/20/V00012556                  Koncese na služby   Otevřené řízení
# 14231  N006/20/V00023730          Veřejná zakázka na služby   Otevřené řízení
# 6172   N006/19/V00027756          Veřejná zakázka na služby   Otevřené řízení
# 29572  N006/16/V00000391          Veřejná zakázka na služby   Otevřené řízení
# 30520  N006/18/V00003757          Veřejná zakázka na služby   Otevřené řízení
# 6171   N006/19/V00027737         Veřejná zakázka na dodávky   Otevřené řízení
# 31350  N006/19/V00007913         Veřejná zakázka na dodávky   Otevřené řízení
# 14823  N006/19/V00026074         Veřejná zakázka na dodávky   Otevřené řízení
#
#        contact_person_id  contracting_authority_id  supplier_id
# 31329               1892                       155         1379
# 31340               1412                       155         1379
# 5621                 273                         4         4307
# 9041                1645                         1         7597
# 27320               2951                      1278        11131
# 31339               1412                       155         1379
# 12692               1974                       404         7252
# 21701               1427                      1060         5756
# 21702               1427                      1060         9582
# 445                  205                       110          557
# 21189                115                        85         1468
# 21190                115                        85         9582
# 26418                709                       284          473
# 12034               2032                       851          232
# 14097               1347                       709         7804
# 28529                502                       252           93
# 25354               2609                      1246        10743
# 28530                502                       252          460
# 31401               3166                       420         3930
# 12254                392                       214         7183
# 23393               2788                      1210        10156
# 11679                453                       589         1094
# 26311                392                       214        10889
# 20772               2609                      1135         9474
# 14067               1347                       709         4366
# 22558                392                       214        10037
# 29268               3046                       264        11672
# 761                  370                       110          986
# 25283                920                       401        10634
# 3875                1055                       452         3239
# 20410                578                         1         9383
# 26947               2937                       902         1013
# 14068               1347                       709         4333
# 14066               1347                       709         7795
# 16311                 72                         1         8233
# 14069               1347                       709         7796
# 3898                1055                       452          408
# 10805                578                         1         6624
# 18267                311                       186         8814
# 16013               2246                         1         6128
# 26501               1373                        99         3441
# 14231                815                         1          303
# 6172                1395                       294         4602
# 29572               3062                       615        11777
# 30520                651                       267        12064
# 6171                1395                       294         4601
# 31350               1412                       155         1379
# 14823               2246                         1         8007

# %%
plt.rcParams.update({'font.size': 16})
plt.figure(figsize=(12, 6))
barplot = sns.countplot(y='public_contract_regime', data=dataframes['procurement'])
plt.title('Počet veřejných zakázek dle režimu veřejné zakázky')
plt.xlabel('Počet')
plt.ylabel('Režim veřejné zakázky')
plt.xlim(0, dataframes['procurement']['public_contract_regime'].value_counts().max() * 1.1)
for p in barplot.patches:
    width = p.get_width()
    barplot.text(width,
                 p.get_y() + p.get_height() / 2,
                 ' {:1.0f}'.format(width),
                 ha = 'left')
plt.show()

# %%
plt.figure(figsize=(12, 6))
barplot = sns.countplot(y='type', data=dataframes['procurement'])
# apply translation
#barplot.set_yticklabels([dict_type[y.get_text()] for y in barplot.get_yticklabels()])
plt.title('Počet veřejných zakázek dle typu veřejné zakázky')
plt.ylabel('Typ veřejné zakázky')
plt.xlabel('Počet')
plt.xlim(0, dataframes['procurement']['type'].value_counts().max() * 1.1)
for p in barplot.patches:
    width = p.get_width()
    barplot.text(width,
                 p.get_y() + p.get_height() / 2,
                 ' {:1.0f}'.format(width),
                 ha = 'left')

# %%
data = dataframes['procurement'].groupby(['type', 'public_contract_regime']).size().unstack().sort_values(by='Nadlimitní veřejná zakázka', ascending=False)
# selekce pouze tří nejčastějších typů veřejných zakázek 
data = data.loc[['Veřejná zakázka na služby', 'Veřejná zakázka na stavební práce', 'Veřejná zakázka na dodávky']]
width = 0.5
half_width = width / 2
barplot = data.plot(kind='bar', figsize=(18, 9), width=0.5)
# logarimtická škála na y-ové ose
plt.yscale('log')


l = plt.legend()
l.set_title('Režim veřejné zakázky')
plt.xticks(rotation=30)
# přidání hodnot na sloupce
for p in barplot.patches:
    width = p.get_width()
    plt.text((p.get_x() + width / 2),
             (p.get_height() + 1) * 1.1,
             ' {:1.0f}'.format(p.get_height()),
             ha = 'center', va = 'bottom')


plt.title('Počet veřejných zakázek dle typu a režimu veřejné zakázky', fontsize=26)
plt.xlabel('Typ veřejné zakázky', fontsize=24)
plt.ylabel('Počet', fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=18)
plt.ylim(1, 10e6)
plt.show()

# %%
data_tmp = dataframes['procurement']["type_of_procedure"].value_counts().sort_values(ascending=False)

data_tmp = data_tmp.reset_index()
data_tmp.columns = ['type_of_procedure', 'count']

plt.figure(figsize=(18, 9))
barplot = sns.barplot(y='type_of_procedure', x='count', data=data_tmp, order=data_tmp['type_of_procedure'])
plt.title('Počet veřejných zakázek dle druhu zadávacího řízení')
plt.xlabel('Počet')
plt.ylabel('Druh zadávacího řízení')


for p in barplot.patches:
    width = p.get_width()
    plt.text(width,
             p.get_y() + p.get_height() / 2,
             ' {:1.0f}'.format(width),
             ha = 'left')

plt.show()

# %% [markdown]
# Nadlimitní veřejné zakázky v režimu přímého zadání:

# %%
view = dataframes['procurement'].loc[dataframes['procurement']['type_of_procedure'] == 'Přímé zadání']
view["public_contract_regime"].value_counts()
view[view["public_contract_regime"] == 'Nadlimitní veřejná zakázka']
# Out:
#           id bids_submission_deadline code_from_nipez_codelist  \
# 3115    7110                      NaN                      NaN
# 3175    3173                      NaN               64200000-8
# 6113    7024                      NaN                      NaN
# 13223  13276                      NaN               22000000-0
# 18099  18126                      NaN               70220000-9
# 22326  22274                      NaN               45214620-2
# 30556  30623                      NaN                      NaN
# 30589  30656                      NaN               73000000-2
#
#        contract_price  contract_price_vat  contract_price_with_amendments  \
# 3115     4.000000e+08        4.840000e+08                    4.000000e+08
# 3175     5.808000e+06        7.027680e+06                    5.808000e+06
# 6113     1.652893e+09        2.000000e+09                    1.652893e+09
# 13223    1.288000e+07        1.558400e+07                    1.288000e+07
# 18099    1.422537e+07        1.721270e+07                    1.422537e+07
# 22326    0.000000e+00        0.000000e+00                    0.000000e+00
# 30556    0.000000e+00        0.000000e+00                    0.000000e+00
# 30589    0.000000e+00        0.000000e+00                    0.000000e+00
#
#        contract_price_with_amendments_vat date_of_contract_close  \
# 3115                         4.840000e+08             2020-10-09
# 3175                         7.027680e+06             2023-11-13
# 6113                         2.000000e+09             2021-11-30
# 13223                        1.558400e+07             2022-07-18
# 18099                        1.721270e+07             2023-07-25
# 22326                        0.000000e+00             2019-01-17
# 30556                        0.000000e+00             2018-10-08
# 30589                        0.000000e+00             2019-09-27
#
#       date_of_publication is_association_of_suppliers  \
# 3115                  NaN                       False
# 3175                  NaN                       False
# 6113                  NaN                       False
# 13223          2022-07-25                       False
# 18099          2023-08-30                       False
# 22326                 NaN                       False
# 30556          2018-12-11                       False
# 30589          2019-10-21                       False
#
#                                         procurement_name  \
# 3115                 Nákup munice 2019/III - 122 KS - RD
# 3175          Mobilní telekomunikační služby_(CNS_MF ČR)
# 6113                 Nákup munice 2022/I - malorážová RD
# 13223           Výroba a dodání Vízových štítků pro OAMP
# 18099              Smlouva o nájmu kancelářských prostor
# 22326                            Projekt HotBENT - Nagra
# 30556  Smlouva o nájmu samostatné části prostor Alter...
# 30589                         Projekt MaCoTe II - Koroze
#
#                            name_from_nipez_codelist place_of_performance  \
# 3115                                            NaN                  NaN
# 3175                         Telekomunikační služby      Česká republika
# 6113                                            NaN                  NaN
# 13223      Tiskařské výrobky a související produkty   Hlavní město Praha
# 18099  Pronájem nebo leasing nebytových nemovitostí   Hlavní město Praha
# 22326    Výstavba výzkumných a testovacích zařízení          Switzerland
# 30556                                           NaN                  NaN
# 30589           Výzkum a vývoj a související služby          Switzerland
#
#            public_contract_regime      system_number  \
# 3115   Nadlimitní veřejná zakázka  N006/23/V00007884
# 3175   Nadlimitní veřejná zakázka  N006/22/V00012130
# 6113   Nadlimitní veřejná zakázka  N006/23/V00007865
# 13223  Nadlimitní veřejná zakázka  N006/22/V00016474
# 18099  Nadlimitní veřejná zakázka  N006/23/V00024107
# 22326  Nadlimitní veřejná zakázka  N006/19/V00002471
# 30556  Nadlimitní veřejná zakázka  N006/18/V00027182
# 30589  Nadlimitní veřejná zakázka  N006/19/V00030475
#
#                              type type_of_procedure  contact_person_id  \
# 3115   Veřejná zakázka na dodávky      Přímé zadání                 97
# 3175    Veřejná zakázka na služby      Přímé zadání                473
# 6113   Veřejná zakázka na dodávky      Přímé zadání                 97
# 13223  Veřejná zakázka na dodávky      Přímé zadání                745
# 18099   Veřejná zakázka na služby      Přímé zadání               2439
# 22326   Veřejná zakázka na služby      Přímé zadání                651
# 30556   Veřejná zakázka na služby      Přímé zadání                651
# 30589  Veřejná zakázka na dodávky      Přímé zadání                651
#
#        contracting_authority_id  supplier_id
# 3115                          1         1920
# 3175                        240          121
# 6113                          1         5081
# 13223                       144         1764
# 18099                        88         8777
# 22326                       267         9885
# 30556                       267         9914
# 30589                       267         9885

# %% [markdown]
# Shlukování kódů NIPEZ podle prvních dvou znaků (obecnější kategorie):

# %%
procurement_view = dataframes['procurement']
procurement_view['code'] = procurement_view['code_from_nipez_codelist'].str[:2]
procurement_view
# Out:
#           id bids_submission_deadline code_from_nipez_codelist  \
# 0          1                      NaN               15710000-8
# 1          2                      NaN               50110000-9
# 2          3                      NaN                      NaN
# 3          4                      NaN               90511000-2
# 4          5                      NaN               90500000-2
# ...      ...                      ...                      ...
# 31548  31623                      NaN               90500000-2
# 31549  31624                      NaN               30121100-4
# 31550  31625                      NaN               09123000-7
# 31551  31626               2023-03-01               50100000-6
# 31552  31627               2023-02-16               30200000-1
#
#        contract_price  contract_price_vat  contract_price_with_amendments  \
# 0            38973.48            44820.00                        38973.48
# 1             9832.02            11896.74                         9832.02
# 2           130000.00           130000.00                       130000.00
# 3            26580.00            32161.80                        26580.00
# 4             8468.00             9314.80                         8468.00
# ...               ...                 ...                             ...
# 31548            0.00                0.00                            0.00
# 31549            0.00                0.00                            0.00
# 31550            0.00                0.00                            0.00
# 31551       141855.33           171644.95                       141855.33
# 31552        63940.00            77367.40                        63940.00
#
#        contract_price_with_amendments_vat date_of_contract_close  \
# 0                                44820.00             2022-03-02
# 1                                11896.74             2023-11-23
# 2                               130000.00             2022-02-24
# 3                                32161.80             2022-03-07
# 4                                 9314.80             2023-10-24
# ...                                   ...                    ...
# 31548                                0.00             2020-06-24
# 31549                                0.00             2021-06-10
# 31550                                0.00             2020-07-03
# 31551                           171644.95             2023-03-14
# 31552                            77367.40             2023-03-13
#
#       date_of_publication is_association_of_suppliers  ...  \
# 0              2022-03-02                       False  ...
# 1              2023-11-30                       False  ...
# 2              2022-03-02                       False  ...
# 3              2022-03-07                       False  ...
# 4              2023-10-24                       False  ...
# ...                   ...                         ...  ...
# 31548          2021-03-22                       False  ...
# 31549          2021-06-20                       False  ...
# 31550          2020-07-30                       False  ...
# 31551          2023-02-15                       False  ...
# 31552          2023-02-07                       False  ...
#
#                                 name_from_nipez_codelist place_of_performance  \
# 0       Průmyslová krmiva pro hospodářská a jiná zvířata       Liberecký kraj
# 1      Opravy a údržba motorových vozidel a příslušen...       Jihočeský kraj
# 2                                                    NaN                  NaN
# 3                                            Sběr odpadu       Liberecký kraj
# 4         Služby související s likvidací odpadů a odpady     Středočeský kraj
# ...                                                  ...                  ...
# 31548     Služby související s likvidací odpadů a odpady   Hlavní město Praha
# 31549                              Fotokopírovací stroje   Hlavní město Praha
# 31550                                         Zemní plyn      Česká republika
# 31551  Opravy a údržba vozidel a příslušenství k nim ...            Jihozápad
# 31552                                           Počítače     Středočeský kraj
#
#                public_contract_regime      system_number  \
# 0                                 NaN  N006/22/V00004456
# 1                                 NaN  N006/23/V00033550
# 2      Veřejná zakázka malého rozsahu  N006/22/V00004676
# 3                                 NaN  N006/22/V00004924
# 4                                 NaN  N006/23/V00030140
# ...                               ...                ...
# 31548  Veřejná zakázka malého rozsahu  N006/21/V00006509
# 31549  Veřejná zakázka malého rozsahu  N006/21/V00015961
# 31550      Nadlimitní veřejná zakázka  N006/20/V00019093
# 31551  Veřejná zakázka malého rozsahu  N006/23/V00002968
# 31552  Veřejná zakázka malého rozsahu  N006/23/V00003309
#
#                              type  \
# 0      Veřejná zakázka na dodávky
# 1       Veřejná zakázka na služby
# 2      Veřejná zakázka na dodávky
# 3       Veřejná zakázka na služby
# 4       Veřejná zakázka na služby
# ...                           ...
# 31548   Veřejná zakázka na služby
# 31549  Veřejná zakázka na dodávky
# 31550  Veřejná zakázka na dodávky
# 31551   Veřejná zakázka na služby
# 31552  Veřejná zakázka na dodávky
#
#                                        type_of_procedure contact_person_id  \
# 0      Zadávání VZ na základě rámcové dohody bez obno...                 1
# 1      Zadávání VZ na základě rámcové dohody bez obno...                 2
# 2                                         Otevřená výzva                 1
# 3      Zadávání VZ na základě rámcové dohody bez obno...                 1
# 4      Zadávání VZ na základě rámcové dohody bez obno...                 3
# ...                                                  ...               ...
# 31548                                     Uzavřená výzva              3174
# 31549                                     Uzavřená výzva              3174
# 31550                      Jednací řízení bez uveřejnění              1559
# 31551                                     Otevřená výzva               897
# 31552                                     Otevřená výzva               717
#
#        contracting_authority_id  supplier_id  code
# 0                             1            1    15
# 1                             1            2    50
# 2                             1            3   NaN
# 3                             1            4    90
# 4                             1            5    90
# ...                         ...          ...   ...
# 31548                       420         1162    90
# 31549                       420          585    30
# 31550                       179          874    09
# 31551                         1        12336    50
# 31552                        92          398    30
#
# [31553 rows x 21 columns]

# %% [markdown]
# Příklad špatných cen s DPH:

# %%
wrong_vat = dataframes['procurement'][dataframes['procurement']['contract_price_with_amendments_vat'] / dataframes['procurement']['contract_price_with_amendments'] > 1.211]
wrong_vat.sort_values(by='contract_price_with_amendments_vat', ascending=False)
# Out:
#           id bids_submission_deadline code_from_nipez_codelist  \
# 1393    1400               2023-03-10               38110000-9
# 10077  10127               2021-06-21               18331000-8
# 26489  26530                      NaN                      NaN
# 27746  27746               2023-03-08               72300000-8
# 30707  30774               2021-10-15               72222300-0
# ...      ...                      ...                      ...
# 31288  31363                      NaN                      NaN
# 27730  27730               2020-07-21               79713000-5
# 6834    6831               2023-04-13               30120000-6
# 22914  22976               2023-05-23               09310000-5
# 24738  24790               2023-05-05               50313000-2
#
#        contract_price  contract_price_vat  contract_price_with_amendments  \
# 1393     1.939812e+08        4.553075e+14                    1.939812e+08
# 10077    5.800000e+07        7.064458e+12                    5.800000e+07
# 26489    1.957937e+06        4.638558e+12                    1.957937e+06
# 27746    1.730709e+07        3.624397e+12                    1.730709e+07
# 30707    1.702050e+07        3.505356e+12                    1.702050e+07
# ...               ...                 ...                             ...
# 31288    3.300000e+02        4.000000e+02                    3.300000e+02
# 27730    2.163000e+01        1.246300e+02                    2.163000e+01
# 6834     1.600000e+00        1.940000e+00                    1.600000e+00
# 22914    1.230000e+00        1.490000e+00                    1.230000e+00
# 24738    3.000000e-02        4.000000e-02                    3.000000e-02
#
#        contract_price_with_amendments_vat date_of_contract_close  \
# 1393                         4.553075e+14             2023-06-29
# 10077                        7.064458e+12             2021-08-12
# 26489                        4.638558e+12             2023-05-03
# 27746                        3.624397e+12             2023-04-12
# 30707                        3.505356e+12             2022-04-01
# ...                                   ...                    ...
# 31288                        4.000000e+02             2021-12-28
# 27730                        1.246300e+02             2020-08-17
# 6834                         1.940000e+00             2023-04-24
# 22914                        1.490000e+00             2023-06-15
# 24738                        4.000000e-02             2023-05-23
#
#       date_of_publication is_association_of_suppliers  ...  \
# 1393           2023-02-10                       False  ...
# 10077          2021-05-10                       False  ...
# 26489          2023-05-04                       False  ...
# 27746          2023-02-02                       False  ...
# 30707          2021-08-23                       False  ...
# ...                   ...                         ...  ...
# 31288          2023-03-16                       False  ...
# 27730          2020-07-07                       False  ...
# 6834           2023-03-31                       False  ...
# 22914          2023-04-20                       False  ...
# 24738          2023-04-25                        True  ...
#
#                                 name_from_nipez_codelist place_of_performance  \
# 1393                                 Navigační přístroje      Pardubický kraj
# 10077                Trička s krátkým rukávem (T-shirts)      Česká republika
# 26489                                                NaN                  NaN
# 27746                                      Datové služby   Hlavní město Praha
# 30707                    Služby informačních technologií      Česká republika
# ...                                                  ...                  ...
# 31288                                                NaN                  NaN
# 27730                                     Strážní služby    Jihomoravský kraj
# 6834   Zařízení pro fotokopírování a ofsetové tiskařs...      Česká republika
# 22914                                 Elektrická energie       Olomoucký kraj
# 24738             Opravy a údržba reprografické techniky   Hlavní město Praha
#
#                public_contract_regime      system_number  \
# 1393       Nadlimitní veřejná zakázka  N006/23/V00003252
# 10077      Nadlimitní veřejná zakázka  N006/21/V00008639
# 26489                             NaN  N006/23/V00012432
# 27746      Nadlimitní veřejná zakázka  N006/23/V00001306
# 30707      Nadlimitní veřejná zakázka  N006/21/V00020484
# ...                               ...                ...
# 31288                             NaN  N006/23/V00007134
# 27730  Veřejná zakázka malého rozsahu  N006/20/V00013509
# 6834   Veřejná zakázka malého rozsahu  N006/23/V00008616
# 22914      Nadlimitní veřejná zakázka  N006/23/V00010837
# 24738  Veřejná zakázka malého rozsahu  N006/23/V00010198
#
#                                     type type_of_procedure contact_person_id  \
# 1393          Veřejná zakázka na dodávky   Otevřené řízení               531
# 10077         Veřejná zakázka na dodávky   Otevřené řízení              1829
# 26489  Veřejná zakázka na stavební práce    Uzavřená výzva              2915
# 27746          Veřejná zakázka na služby   Otevřené řízení              1150
# 30707          Veřejná zakázka na služby   Otevřené řízení              1559
# ...                                  ...               ...               ...
# 31288         Veřejná zakázka na dodávky    Uzavřená výzva              2496
# 27730          Veřejná zakázka na služby    Otevřená výzva              1512
# 6834           Veřejná zakázka na služby    Otevřená výzva               563
# 22914         Veřejná zakázka na dodávky   Otevřené řízení              1960
# 24738          Veřejná zakázka na služby    Otevřená výzva               927
#
#        contracting_authority_id  supplier_id  code
# 1393                          1         1475    38
# 10077                       110         3267    18
# 26489                       804         7838   NaN
# 27746                       166          972    72
# 30707                       179         2150    72
# ...                         ...          ...   ...
# 31288                      1083        12280   NaN
# 27730                       605         1517    79
# 6834                         99          585    30
# 22914                       805          874    09
# 24738                        76         8647    50
#
# [90 rows x 21 columns]

# %% [markdown]
# Odstranění řádků s chybnými cenami s DPH:

# %%
dataframes['procurement'].drop(wrong_vat.index, inplace=True)

# %% [markdown]
# Nové statistiky po odstranění špatných cen s DPH pro tabulku procurement:

# %%
basic_stats(dataframes['procurement'])
# Out:
# Počet řádek je 31463 a počet sloupců je 21
# Statitiky pro číselné příznaky:
#                  id  contract_price  contract_price_vat  \
# count  31463.000000    3.146300e+04        3.146300e+04
# mean   15843.221053    7.750968e+06        9.247200e+06
# std     9114.908568    1.078742e+08        1.282497e+08
# min        1.000000    0.000000e+00        0.000000e+00
# 25%     7965.500000    1.200000e+04        1.421145e+04
# 50%    15851.000000    1.701700e+05        2.016525e+05
# 75%    23729.500000    1.192255e+06        1.426225e+06
# max    31627.000000    1.239521e+10        1.499820e+10
#
#        contract_price_with_amendments  contract_price_with_amendments_vat  \
# count                    3.146300e+04                        3.146300e+04
# mean                     7.850865e+06                        9.367668e+06
# std                      1.082823e+08                        1.287504e+08
# min                      0.000000e+00                        0.000000e+00
# 25%                      1.200000e+04                        1.422960e+04
# 50%                      1.704388e+05                        2.019248e+05
# 75%                      1.194557e+06                        1.427878e+06
# max                      1.239521e+10                        1.499820e+10
#
#        contact_person_id  contracting_authority_id   supplier_id
# count       31463.000000              31463.000000  31463.000000
# mean          924.769316                154.164956   2946.705654
# std           775.569780                236.413128   3177.517827
# min             1.000000                  1.000000      1.000000
# 25%           293.000000                  1.000000    481.000000
# 50%           695.000000                 77.000000   1659.000000
# 75%          1418.000000                191.000000   4449.000000
# max          3174.000000               1364.000000  12336.000000
# Chybějící hodnoty v %:
# id                                     0.000000
# bids_submission_deadline              49.890347
# code_from_nipez_codelist               5.399994
# contract_price                         0.000000
# contract_price_vat                     0.000000
# contract_price_with_amendments         0.000000
# contract_price_with_amendments_vat     0.000000
# date_of_contract_close                 0.031783
# date_of_publication                    4.478276
# is_association_of_suppliers            0.022248
# procurement_name                       0.000000
# name_from_nipez_codelist               5.399994
# place_of_performance                  10.914407
# public_contract_regime                33.722150
# system_number                          0.000000
# type                                   0.063567
# type_of_procedure                      0.000000
# contact_person_id                      0.000000
# contracting_authority_id               0.000000
# supplier_id                            0.000000
# code                                   5.399994
# dtype: float64
# Příklad záznamů z tabulky:
#    id bids_submission_deadline code_from_nipez_codelist  contract_price  \
# 0   1                      NaN               15710000-8        38973.48
# 1   2                      NaN               50110000-9         9832.02
# 2   3                      NaN                      NaN       130000.00
# 3   4                      NaN               90511000-2        26580.00
# 4   5                      NaN               90500000-2         8468.00
# 5   6                      NaN               24612000-7        90525.00
# 6   7                      NaN               15710000-8       103600.35
# 7   8                      NaN               15710000-8        23508.00
# 8   9                      NaN               45000000-7      1078673.00
# 9  10                      NaN               03322000-2       130000.00
#
#    contract_price_vat  contract_price_with_amendments  \
# 0            44820.00                        38973.48
# 1            11896.74                         9832.02
# 2           130000.00                       130000.00
# 3            32161.80                        26580.00
# 4             9314.80                         8468.00
# 5           109535.25                        90525.00
# 6           119141.40                       103600.35
# 7            27034.20                        23508.00
# 8          1305194.33                      1078673.00
# 9           130000.00                       130000.00
#
#    contract_price_with_amendments_vat date_of_contract_close  \
# 0                            44820.00             2022-03-02
# 1                            11896.74             2023-11-23
# 2                           130000.00             2022-02-24
# 3                            32161.80             2022-03-07
# 4                             9314.80             2023-10-24
# 5                           109535.25             2022-03-31
# 6                           119141.40             2022-04-01
# 7                            27034.20             2022-04-28
# 8                          1305194.33             2023-11-24
# 9                           130000.00             2022-03-31
#
#   date_of_publication is_association_of_suppliers  ...  \
# 0          2022-03-02                       False  ...
# 1          2023-11-30                       False  ...
# 2          2022-03-02                       False  ...
# 3          2022-03-07                       False  ...
# 4          2023-10-24                       False  ...
# 5          2022-04-01                       False  ...
# 6          2022-04-01                       False  ...
# 7          2022-05-03                       False  ...
# 8          2023-11-30                       False  ...
# 9          2022-04-21                       False  ...
#
#                             name_from_nipez_codelist place_of_performance  \
# 0   Průmyslová krmiva pro hospodářská a jiná zvířata       Liberecký kraj
# 1  Opravy a údržba motorových vozidel a příslušen...       Jihočeský kraj
# 2                                                NaN                  NaN
# 3                                        Sběr odpadu       Liberecký kraj
# 4     Služby související s likvidací odpadů a odpady     Středočeský kraj
# 5                                    Různé výbušniny       Liberecký kraj
# 6   Průmyslová krmiva pro hospodářská a jiná zvířata       Liberecký kraj
# 7   Průmyslová krmiva pro hospodářská a jiná zvířata       Liberecký kraj
# 8                                     Stavební práce        Plzeňský kraj
# 9                                Hospodářská zvířata                  NaN
#
#            public_contract_regime      system_number  \
# 0                             NaN  N006/22/V00004456
# 1                             NaN  N006/23/V00033550
# 2  Veřejná zakázka malého rozsahu  N006/22/V00004676
# 3                             NaN  N006/22/V00004924
# 4                             NaN  N006/23/V00030140
# 5                             NaN  N006/22/V00007031
# 6                             NaN  N006/22/V00007590
# 7                             NaN  N006/22/V00009380
# 8  Veřejná zakázka malého rozsahu  N006/23/V00034233
# 9  Veřejná zakázka malého rozsahu  N006/22/V00009384
#
#                                 type  \
# 0         Veřejná zakázka na dodávky
# 1          Veřejná zakázka na služby
# 2         Veřejná zakázka na dodávky
# 3          Veřejná zakázka na služby
# 4          Veřejná zakázka na služby
# 5          Veřejná zakázka na služby
# 6         Veřejná zakázka na dodávky
# 7         Veřejná zakázka na dodávky
# 8  Veřejná zakázka na stavební práce
# 9         Veřejná zakázka na dodávky
#
#                                    type_of_procedure contact_person_id  \
# 0  Zadávání VZ na základě rámcové dohody bez obno...                 1
# 1  Zadávání VZ na základě rámcové dohody bez obno...                 2
# 2                                     Otevřená výzva                 1
# 3  Zadávání VZ na základě rámcové dohody bez obno...                 1
# 4  Zadávání VZ na základě rámcové dohody bez obno...                 3
# 5  Zadávání VZ na základě rámcové dohody bez obno...                 1
# 6  Zadávání VZ na základě rámcové dohody bez obno...                 1
# 7  Zadávání VZ na základě rámcové dohody bez obno...                 1
# 8                                     Uzavřená výzva                 4
# 9                                     Otevřená výzva                 1
#
#    contracting_authority_id  supplier_id  code
# 0                         1            1    15
# 1                         1            2    50
# 2                         1            3   NaN
# 3                         1            4    90
# 4                         1            5    90
# 5                         1            6    24
# 6                         1            7    15
# 7                         1            8    15
# 8                         2            9    45
# 9                         1           10    03
#
# [10 rows x 21 columns]

# %% [markdown]
# Celková cena veřejných zakázek s DPH a dodatky:

# %%
price_vat_sum = dataframes['procurement']['contract_price_with_amendments_vat'].sum()
print(f"Celková cena veřejných zakázek s DPH a dodatky je {price_vat_sum:,} Kč")
# Out:
# Celková cena veřejných zakázek s DPH a dodatky je 294,734,950,313.46 Kč

# %% [markdown]
# Procento veřejných zakázek s cenou 0:

# %%
percentage_0 = dataframes['procurement'][dataframes['procurement']['contract_price_with_amendments_vat'] == 0].shape[0] / dataframes['procurement'].shape[0] * 100
print(f"Procento veřejných zakázek s cenou 0 je {percentage_0:.2f} %")
# Out:
# Procento veřejných zakázek s cenou 0 je 10.75 %

# %% [markdown]
# Procento odlehlých hodnot v ceně veřejných zakázek s DPH a dodatky, určených pomocí metody IQR:

# %%
Q1 = dataframes['procurement']['contract_price_with_amendments_vat'].quantile(0.25)
Q3 = dataframes['procurement']['contract_price_with_amendments_vat'].quantile(0.75)
IQR = Q3 - Q1
outliers = dataframes['procurement'][(dataframes['procurement']['contract_price_with_amendments_vat'] < (Q1 - 1.5 * IQR)) | (dataframes['procurement']['contract_price_with_amendments_vat'] > (Q3 + 1.5 * IQR))]
display(outliers.sort_values(by='contract_price_with_amendments_vat', ascending=False))
print(f"Procento odlehlých hodnot: {outliers.shape[0] / dataframes['procurement'].shape[0] * 100:.2f} %")
# Out:
#           id bids_submission_deadline code_from_nipez_codelist  \
# 14352  14403               2023-08-16               45252300-1
# 27335  27369                      NaN               09123000-7
# 26033  26072               2023-02-14               60210000-3
# 25796  25835               2023-02-13               44610000-9
# 30054  30120               2022-10-24               45000000-7
# ...      ...                      ...                      ...
# 1811    2816               2023-10-06               48822000-6
# 5711    5743                      NaN               45212350-4
# 7816    7843               2023-07-13               45232400-6
# 22717  22643               2021-09-03               37481000-3
# 10886  10935                      NaN               33651600-4
#
#        contract_price  contract_price_vat  contract_price_with_amendments  \
# 14352    1.239521e+10        1.499820e+10                    1.239521e+10
# 27335    7.024773e+09        8.499983e+09                    7.024773e+09
# 26033    5.684083e+09        5.684083e+09                    5.684083e+09
# 25796    3.798000e+09        4.595580e+09                    3.798000e+09
# 30054    3.146685e+09        3.807489e+09                    3.146685e+09
# ...               ...                 ...                             ...
# 1811     2.939764e+06        3.557114e+06                    2.939764e+06
# 5711     2.938908e+06        3.556078e+06                    2.938908e+06
# 7816     2.938068e+06        3.555062e+06                    2.938068e+06
# 22717    2.938000e+06        3.554980e+06                    2.938000e+06
# 10886    3.228300e+06        3.551130e+06                    3.228300e+06
#
#        contract_price_with_amendments_vat date_of_contract_close  \
# 14352                        1.499820e+10             2023-09-26
# 27335                        8.499983e+09             2022-04-29
# 26033                        5.684083e+09             2023-05-02
# 25796                        4.595580e+09             2023-05-09
# 30054                        3.807489e+09             2023-02-23
# ...                                   ...                    ...
# 1811                         3.557114e+06             2023-10-23
# 5711                         3.556078e+06             2023-05-18
# 7816                         3.555062e+06             2023-08-31
# 22717                        3.554980e+06             2021-10-21
# 10886                        3.551130e+06             2023-07-14
#
#       date_of_publication is_association_of_suppliers  ...  \
# 14352          2020-12-21                        True  ...
# 27335          2022-05-04                       False  ...
# 26033          2022-10-31                       False  ...
# 25796          2022-03-11                       False  ...
# 30054          2022-07-04                        True  ...
# ...                   ...                         ...  ...
# 1811           2023-09-07                       False  ...
# 5711           2023-05-22                       False  ...
# 7816           2023-06-28                       False  ...
# 22717          2021-08-17                       False  ...
# 10886          2023-07-26                       False  ...
#
#                                 name_from_nipez_codelist place_of_performance  \
# 14352                           Výstavba spaloven odpadů     Středočeský kraj
# 27335                                         Zemní plyn      Česká republika
# 26033                  Služby veřejné železniční dopravy      Česká republika
# 25796  Nádrže, zásobníky, podobné nádoby a tlakové ná...       Jihočeský kraj
# 30054                                     Stavební práce       Liberecký kraj
# ...                                                  ...                  ...
# 1811                                  Počítačové servery   Hlavní město Praha
# 5711   Historicky nebo architektonicky mimořádně zají...        Plzeňský kraj
# 7816               Stavební práce na výstavbě kanalizace       Liberecký kraj
# 22717                    Stroje na úpravu ledových ploch      Pardubický kraj
# 10886                                     Očkovací látky   Hlavní město Praha
#
#                public_contract_regime      system_number  \
# 14352      Nadlimitní veřejná zakázka  N006/20/V00030842
# 27335      Nadlimitní veřejná zakázka  N006/22/V00009480
# 26033      Nadlimitní veřejná zakázka  N006/22/V00028809
# 25796      Nadlimitní veřejná zakázka  N006/22/V00005142
# 30054      Nadlimitní veřejná zakázka  N006/22/V00017355
# ...                               ...                ...
# 1811       Nadlimitní veřejná zakázka  N006/23/V00019089
# 5711                              NaN  N006/23/V00014158
# 7816   Veřejná zakázka malého rozsahu  N006/23/V00017384
# 22717      Podlimitní veřejná zakázka  N006/21/V00021335
# 10886      Nadlimitní veřejná zakázka  N006/23/V00014093
#
#                                     type               type_of_procedure  \
# 14352  Veřejná zakázka na stavební práce    Jednací řízení s uveřejněním
# 27335         Veřejná zakázka na dodávky   Jednací řízení bez uveřejnění
# 26033          Veřejná zakázka na služby                 Otevřené řízení
# 25796         Veřejná zakázka na dodávky    Jednací řízení s uveřejněním
# 30054  Veřejná zakázka na stavební práce                 Otevřené řízení
# ...                                  ...                             ...
# 1811          Veřejná zakázka na dodávky                 Otevřené řízení
# 5711   Veřejná zakázka na stavební práce                  Uzavřená výzva
# 7816   Veřejná zakázka na stavební práce                  Otevřená výzva
# 22717         Veřejná zakázka na dodávky  Zjednodušené podlimitní řízení
# 10886         Veřejná zakázka na dodávky               Zadávání VZ v DNS
#
#       contact_person_id  contracting_authority_id  supplier_id  code
# 14352              2229                        70          112    45
# 27335               419                       175         3509    09
# 26033              2895                       379        10843    60
# 25796              2888                        70          463    44
# 30054              3087                       322         4849    45
# ...                 ...                       ...          ...   ...
# 1811                108                        81          398    48
# 5711               1319                       543         3295    45
# 7816                527                       261         5443    45
# 22717               766                       344         9961    37
# 10886                80                        69         1647    33
#
# [4389 rows x 21 columns]
# Procento odlehlých hodnot: 13.95 %

# %% [markdown]
# Příprava dat pro vizualizaci bez odlehlých hodnot:

# %%
data_witout_outliers = dataframes['procurement'][~dataframes['procurement'].index.isin(outliers.index)]

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=dataframes['procurement'], x='contract_price_with_amendments_vat', showfliers=False, showmeans=True, meanprops=dict(marker='o', markerfacecolor='red', markeredgecolor='black'), medianprops=dict(color='yellow'))
plt.title('Krabicový graf ceny veřejných zakázek s DPH a dodatky (bez odlehlých pozorování)')
plt.xlabel('Cena veřejné zakázky s DPH a dodatky [Kč]')
plt.show()

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.2, .8)}, figsize=(14, 7))
 
# Box plot
sns.boxplot(ax=ax_box,data=dataframes['procurement'], x='contract_price_with_amendments_vat', showfliers=False, showmeans=True, meanprops=dict(marker='o', markerfacecolor='red', markeredgecolor='black'), medianprops=dict(color='yellow'))
ax_box.set(xlabel='')
ax_hist.set_xlabel('Cena veřejné zakázky s DPH a dodatky [Kč]')
ax_hist.set_ylabel('Počet veřejných zakázek')
ax_box.set_title('Krabicový diagram a histogram ceny veřejných zakázek s DPH a dodatky (bez odlehlých pozorování)')

# Histogram
sns.histplot(ax=ax_hist, data=data_witout_outliers, x='contract_price_with_amendments_vat', bins=int(1 + np.log2(data_witout_outliers.shape[0])))
plt.show()
# Out:
# C:\Users\marti\PycharmProjects\bakalarka\venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Seskupení podle kódu NIPEZ a výpočet součtu cen s DPH a dodatky
n=15
procurement_view_grouped = procurement_view.groupby('code')['contract_price_with_amendments_vat'].sum().reset_index()
m=procurement_view_grouped.shape[0]
# Seřazení podle 'contract_price_with_amendments' sestupně a výběr prvních n kategorií
procurement_view_sorted = procurement_view_grouped.sort_values(by='contract_price_with_amendments_vat', ascending=False).head(n)

# Výpočet celkové sumy cen s DPH a dodatky
total_sum = procurement_view['contract_price_with_amendments_vat'].sum()

# Výpočet sumy cen s DPH a dodatky pro prvních n kategorií
top_n_sum = procurement_view_sorted['contract_price_with_amendments_vat'].sum()

# Výpočet sumy cen s DPH a dodatky pro zbylé kategorie
rest_sum = total_sum - top_n_sum

# Vytvoření nového řádku pro zbylé kategorie
procurement_view_sorted.loc[len(procurement_view_sorted.index)] = ({'code': "Součet pro zbylých {} kódů".format(m-n), 'contract_price_with_amendments_vat': rest_sum})

# Vykreslení sloupcového grafu
plt.figure(figsize=(16, 8))
barplot = sns.barplot(y='code', x='contract_price_with_amendments_vat', data=procurement_view_sorted, errorbar=None)
plt.title('Součet cen vysoutěžených zakázek rozdělených dle kódu NIPEZ')
plt.ylabel('Kód NIPEZ')
plt.xlabel('Součet cen vysoutěžených zakázek [Kč]')
plt.xlim(0, procurement_view_sorted['contract_price_with_amendments_vat'].max() * 1.2)
for p in barplot.patches:
    width = p.get_width()
    formatted_width = '{:,}'.format(int(width)).replace(',', ' ')  # Format the sum with spaces
    plt.text(width,
             p.get_y() + p.get_height() / 2,
             ' {} Kč'.format(formatted_width),
             ha = 'left')
plt.show()

# %%
# Seskupení podle místa plnění a výpočet součtu cen s DPH a dodatky
n=15
procurement_view_grouped = procurement_view.groupby('place_of_performance')['contract_price_with_amendments_vat'].sum().reset_index()
m=procurement_view_grouped.shape[0]
# Seřazení podle 'contract_price_with_amendments' sestupně a výběr prvních n kategorií
procurement_view_sorted = procurement_view_grouped.sort_values(by='contract_price_with_amendments_vat', ascending=False).head(n)

# Součet cen s DPH a dodatky pro jednotlivá místa plnění
total_sum = procurement_view['contract_price_with_amendments_vat'].sum()

# Součet cen s DPH a dodatky pro prvních n míst plnění
top_n_sum = procurement_view_sorted['contract_price_with_amendments_vat'].sum()

# Součet cen s DPH a dodatky pro zbylá místa plnění
rest_sum = total_sum - top_n_sum

# Přidání nového řádku pro zbylá místa plnění
procurement_view_sorted.loc[len(procurement_view_sorted.index)] = ({'place_of_performance': "Součet zbylých {} míst".format(m-n), 'contract_price_with_amendments_vat': rest_sum})

plt.figure(figsize=(14, 7))
barplot = sns.barplot(y='place_of_performance', x='contract_price_with_amendments_vat', data=procurement_view_sorted, errorbar=None)
plt.title('Součet cen s DPH a dodatky veřejných zakázek dle místa plnění')
plt.ylabel('Místo plnění')
plt.xlabel('Součet cen s DPH a dodatky [Kč]')
plt.xlim(0, procurement_view_sorted['contract_price_with_amendments_vat'].max() * 1.2)
for p in barplot.patches:
    width = p.get_width()
    formatted_width = '{:,}'.format(int(width)).replace(',', ' ')  # Format the sum with spaces
    plt.text(width,
             p.get_y() + p.get_height() / 2,
             ' {} Kč'.format(formatted_width),
             ha = 'left')
plt.show()

# %%
p = dataframes['procurement']
contract_price = p[p['contract_price_with_amendments'].between(p['contract_price_with_amendments'].quantile(.05), p['contract_price_with_amendments'].quantile(.95))] 
list_of_types = ['Veřejná zakázka na dodávky', 'Veřejná zakázka na služby', 'Veřejná zakázka na stavební práce']
contract_price = contract_price[contract_price['type'].isin(list_of_types)]

plt.figure(figsize=(14, 7))
sns.boxplot(data=contract_price, x='contract_price_with_amendments', y='type', medianprops=dict(color='yellow'), showfliers=False)

plt.xlabel('Cena veřejné zakázky s dodatky [Kč]')
plt.ylabel('Typ veřejné zakázky')
plt.title('Krabicový diagram ceny veřejných zakázek dle typu veřejné zakázky (bez odlehlých hodnot)')
plt.show()

# %% [markdown]
# Přehled VZ dle ceny s DPH seřazených sestupně:

# %%
dataframes['procurement'].sort_values(by='contract_price_with_amendments_vat', ascending=False)
# Out:
#           id bids_submission_deadline code_from_nipez_codelist  \
# 14352  14403               2023-08-16               45252300-1
# 27335  27369                      NaN               09123000-7
# 26033  26072               2023-02-14               60210000-3
# 25796  25835               2023-02-13               44610000-9
# 30054  30120               2022-10-24               45000000-7
# ...      ...                      ...                      ...
# 28889  28890               2020-11-24               72261000-2
# 15088  15136                      NaN               55322000-3
# 28891  28892                      NaN               71317200-5
# 28892  28893               2019-10-01               72261000-2
# 23553  23605                      NaN               50100000-6
#
#        contract_price  contract_price_vat  contract_price_with_amendments  \
# 14352    1.239521e+10        1.499820e+10                    1.239521e+10
# 27335    7.024773e+09        8.499983e+09                    7.024773e+09
# 26033    5.684083e+09        5.684083e+09                    5.684083e+09
# 25796    3.798000e+09        4.595580e+09                    3.798000e+09
# 30054    3.146685e+09        3.807489e+09                    3.146685e+09
# ...               ...                 ...                             ...
# 28889    0.000000e+00        0.000000e+00                    0.000000e+00
# 15088    0.000000e+00        0.000000e+00                    0.000000e+00
# 28891    0.000000e+00        0.000000e+00                    0.000000e+00
# 28892    0.000000e+00        0.000000e+00                    0.000000e+00
# 23553    0.000000e+00        0.000000e+00                    0.000000e+00
#
#        contract_price_with_amendments_vat date_of_contract_close  \
# 14352                        1.499820e+10             2023-09-26
# 27335                        8.499983e+09             2022-04-29
# 26033                        5.684083e+09             2023-05-02
# 25796                        4.595580e+09             2023-05-09
# 30054                        3.807489e+09             2023-02-23
# ...                                   ...                    ...
# 28889                        0.000000e+00             2021-01-29
# 15088                        0.000000e+00             2020-03-24
# 28891                        0.000000e+00             2018-12-01
# 28892                        0.000000e+00             2019-11-21
# 23553                        0.000000e+00             2020-08-31
#
#       date_of_publication is_association_of_suppliers  ...  \
# 14352          2020-12-21                        True  ...
# 27335          2022-05-04                       False  ...
# 26033          2022-10-31                       False  ...
# 25796          2022-03-11                       False  ...
# 30054          2022-07-04                        True  ...
# ...                   ...                         ...  ...
# 28889          2020-10-23                       False  ...
# 15088          2020-03-24                       False  ...
# 28891          2018-12-07                       False  ...
# 28892          2019-09-02                       False  ...
# 23553          2020-08-31                       False  ...
#
#                                 name_from_nipez_codelist place_of_performance  \
# 14352                           Výstavba spaloven odpadů     Středočeský kraj
# 27335                                         Zemní plyn      Česká republika
# 26033                  Služby veřejné železniční dopravy      Česká republika
# 25796  Nádrže, zásobníky, podobné nádoby a tlakové ná...       Jihočeský kraj
# 30054                                     Stavební práce       Liberecký kraj
# ...                                                  ...                  ...
# 28889                      Podpora programového vybavení   Hlavní město Praha
# 15088                                       Vaření jídel        Plzeňský kraj
# 28891       Služby v oblasti bezpečnosti a zdraví (BOZP)                  NaN
# 28892                      Podpora programového vybavení                Praha
# 23553  Opravy a údržba vozidel a příslušenství k nim ...       Olomoucký kraj
#
#                public_contract_regime      system_number  \
# 14352      Nadlimitní veřejná zakázka  N006/20/V00030842
# 27335      Nadlimitní veřejná zakázka  N006/22/V00009480
# 26033      Nadlimitní veřejná zakázka  N006/22/V00028809
# 25796      Nadlimitní veřejná zakázka  N006/22/V00005142
# 30054      Nadlimitní veřejná zakázka  N006/22/V00017355
# ...                               ...                ...
# 28889      Nadlimitní veřejná zakázka  N006/20/V00025554
# 15088                             NaN  N006/20/V00006352
# 28891  Veřejná zakázka malého rozsahu  N006/18/V00022874
# 28892      Nadlimitní veřejná zakázka  N006/19/V00021828
# 23553                             NaN  N006/20/V00021229
#
#                                     type  \
# 14352  Veřejná zakázka na stavební práce
# 27335         Veřejná zakázka na dodávky
# 26033          Veřejná zakázka na služby
# 25796         Veřejná zakázka na dodávky
# 30054  Veřejná zakázka na stavební práce
# ...                                  ...
# 28889          Veřejná zakázka na služby
# 15088          Veřejná zakázka na služby
# 28891          Veřejná zakázka na služby
# 28892          Veřejná zakázka na služby
# 23553          Veřejná zakázka na služby
#
#                                        type_of_procedure contact_person_id  \
# 14352                       Jednací řízení s uveřejněním              2229
# 27335                      Jednací řízení bez uveřejnění               419
# 26033                                    Otevřené řízení              2895
# 25796                       Jednací řízení s uveřejněním              2888
# 30054                                    Otevřené řízení              3087
# ...                                                  ...               ...
# 28889                                    Otevřené řízení               265
# 15088  Zadávání VZ na základě rámcové dohody bez obno...              2161
# 28891                                     Uzavřená výzva              3021
# 28892                                    Otevřené řízení               265
# 23553  Zadávání VZ na základě rámcové dohody bez obno...               379
#
#        contracting_authority_id  supplier_id  code
# 14352                        70          112    45
# 27335                       175         3509    09
# 26033                       379        10843    60
# 25796                        70          463    44
# 30054                       322         4849    45
# ...                         ...          ...   ...
# 28889                       163         1056    72
# 15088                         1         5173    55
# 28891                        62        11546    71
# 28892                       163         2150    72
# 23553                         1          294    50
#
# [31463 rows x 21 columns]

# %% [markdown]
# Poměr ano / ne hodnot pro příznaky is_association_of_suppliers, is_withdrawn, is_rejected_due_too_low v tabulce offer:

# %%
val_is_asso = dataframes['offer']['is_association_of_suppliers'].value_counts()
val_is_with = dataframes['offer']['is_withdrawn'].value_counts()
val_is_rej = dataframes['offer']['is_rejected_due_too_low'].value_counts()

# display the values in percentage
display(val_is_asso / dataframes['offer'].shape[0] * 100)
display(val_is_with / dataframes['offer'].shape[0] * 100)
display(val_is_rej / dataframes['offer'].shape[0] * 100)
# Out:
# is_association_of_suppliers
# False    98.424749
# True      1.562456
# Name: count, dtype: float64
# is_withdrawn
# False    98.906708
# True      1.080497
# Name: count, dtype: float64
# is_rejected_due_too_low
# False    99.792431
# True      0.196196
# Name: count, dtype: float64

# %% [markdown]
# Nabídky se špatnou cenou s DPH:

# %%
wrong_vat = dataframes['offer'][dataframes['offer']['price_vat'] / dataframes['offer']['price'] > 1.211]
wrong_vat.sort_values(by='price_vat', ascending=False)
# Out:
#           id is_association_of_suppliers is_rejected_due_too_low is_withdrawn  \
# 65337  65389                       False                   False        False
# 56482  56534                       False                   False        False
# 11215  11264                       False                   False        False
# 14999  15051                       False                   False        False
# 59142  59194                       False                   False        False
# ...      ...                         ...                     ...          ...
# 54331  54383                       False                   False        False
# 37317  37368                       False                   False        False
# 37332  37383                       False                   False        False
# 55015  55067                        True                   False        False
# 14273  14325                       False                   False        False
#
#               price     price_vat  company_id  procurement_id
# 65337  2.050583e+08  8.830292e+13         450           29577
# 56482  1.976777e+07  8.206258e+11        1185           25535
# 11215  1.752000e+06  1.729574e+10        1553            5538
# 14999  1.718614e+06  6.204347e+09        5222            7300
# 59142  1.184000e+06  2.945082e+09        1056           26816
# ...             ...           ...         ...             ...
# 54331  1.130000e+00  1.370000e+00        3201           24464
# 37317  8.000000e-01  9.700000e-01        8805           18230
# 37332  8.000000e-01  9.700000e-01        8805           18239
# 55015  3.000000e-02  4.000000e-02        8647           24790
# 14273  1.000000e-02  2.000000e-02         610            6918
#
# [274 rows x 8 columns]

# %% [markdown]
# Odstranění řádků s chybnými cenami s DPH:

# %%
dataframes['offer'].drop(wrong_vat.index, inplace=True)

# %% [markdown]
# Procento odlehlých hodnot v ceně nabídek s DPH, určených pomocí metody IQR:

# %%
Q1 = dataframes['offer']['price_vat'].quantile(0.25)
Q3 = dataframes['offer']['price_vat'].quantile(0.75)
IQR = Q3 - Q1
outliers = dataframes['offer'][(dataframes['offer']['price_vat'] < (Q1 - 1.5 * IQR)) | (dataframes['offer']['price_vat'] > (Q3 + 1.5 * IQR))]
display(outliers.sort_values(by='price_vat', ascending=False))
print(f"Procento odlehlých hodnot: {outliers.shape[0] / dataframes['offer'].shape[0] * 100:.2f} %")
# Out:
#           id is_association_of_suppliers is_rejected_due_too_low is_withdrawn  \
# 7411    7437                       False                   False        False
# 7407    7433                       False                   False        False
# 7412    7438                       False                   False        False
# 2934    2958                       False                   False        False
# 9000    9050                       False                   False        False
# ...      ...                         ...                     ...          ...
# 10546  10597                       False                   False        False
# 35473  35525                       False                   False        False
# 8713    8764                       False                   False        False
# 22541  22536                       False                   False        False
# 63929  63981                       False                   False        False
#
#               price     price_vat  company_id  procurement_id
# 7411   1.145797e+11  1.386414e+11        3167            3765
# 7407   1.130746e+11  1.368203e+11        2106            3765
# 7412   1.108713e+11  1.341542e+11        1152            3765
# 2934   9.370252e+10  1.133800e+11         341            1562
# 9000   3.348099e+10  4.051200e+10        1934            4602
# ...             ...           ...         ...             ...
# 10546  2.821506e+06  3.414022e+06         204            5248
# 35473  2.820000e+06  3.412200e+06        8518           17389
# 8713   2.819800e+06  3.411958e+06         263            4482
# 22541  2.819760e+06  3.411910e+06         124           10918
# 63929  2.819124e+06  3.411140e+06        1331           29029
#
# [8396 rows x 8 columns]
# Procento odlehlých hodnot: 11.98 %

# %% [markdown]
# Příprava dat pro vizualizaci bez odlehlých hodnot:

# %%
data_witout_outliers = dataframes['offer'][~dataframes['offer'].index.isin(outliers.index)]

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.2, .8)}, figsize=(14, 7))
 

sns.boxplot(ax=ax_box,data=dataframes['offer'], x='price_vat', showfliers=False, showmeans=True, meanprops=dict(marker='o', markerfacecolor='red', markeredgecolor='black'), medianprops=dict(color='yellow'))
ax_box.set(xlabel='')
ax_hist.set_xlabel('Cena nabídky s DPH [Kč]')
ax_hist.set_ylabel('Počet nabídek')
ax_box.set_title('Krabicový diagram a histogram ceny nabídek s DPH (bez odlehlých pozorování)')


sns.histplot(ax=ax_hist, data=data_witout_outliers, x='price_vat', bins=int(1 + np.log2(data_witout_outliers.shape[0])))
plt.show()
# Out:
# C:\Users\marti\PycharmProjects\bakalarka\venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Počet nabídek s cenou 0 a procento jejich zastoupení v datech:

# %%
count = dataframes['offer'][dataframes['offer']['price_vat'] == 0].shape[0]
per = dataframes['offer'][dataframes['offer']['price_vat'] == 0].shape[0] / dataframes['offer'].shape[0] * 100
print(f"Počet nabídek s cenou 0 je {count} a procento jejich zastoupení v datech je {per:.2f} %")
# Out:
# Počet nabídek s cenou 0 je 2898 a procento jejich zastoupení v datech je 4.14 %

# %%
mean = dataframes['offer']['price_vat'].mean(skipna=True)
median = dataframes['offer']['price_vat'].median(skipna=True)
print(f"Průměrná cena nabídky s DPH je {mean:,.2f} Kč a medián je {median:,.2f} Kč")
# Out:
# Průměrná cena nabídky s DPH je 21,048,209.92 Kč a medián je 301,290.00 Kč
